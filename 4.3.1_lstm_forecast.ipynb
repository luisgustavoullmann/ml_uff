# %%
! pip install feature_engine==1.8.0 --quiet

# %%
# !pip install optuna==4.8.0 -q

# %%
# !pip uninstall scikit-learn -y
# !pip install scikit-learn==1.5.2 -q
# Out:
# Found existing installation: scikit-learn 1.5.2
# Uninstalling scikit-learn-1.5.2:
#   Successfully uninstalled scikit-learn-1.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# umap-learn 0.5.12 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# hdbscan 0.8.42 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.

# %%
# !pip uninstall lightgbm -y
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm) (1.16.3)

# %%
import torch
print(torch.cuda.is_available()) # Deve retornar True no Colab com GPU ativa
# Out:
# False

# %%
import pandas as pd
import numpy as np
import sys
import gc
import random
import os

import unicodedata
import re

import seaborn as sns
import matplotlib.pyplot as plt

import feature_engine
from feature_engine.selection import (
    RecursiveFeatureElimination,
    DropConstantFeatures,
    DropDuplicateFeatures,
)
import optuna

from sklearn.pipeline import Pipeline
from sklearn.base import clone
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, make_scorer
from sklearn.preprocessing import StandardScaler
import sklearn

import xgboost
import lightgbm
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

import time

import tensorflow as tf

print(f"Versão:")
print(f'Python: {sys.version}')
print(f'Pandas: {pd.__version__}')
print(f'Numpy: {np.__version__}')
print("Feature Engine:", feature_engine.__version__)
print("Scikit-Learn:", sklearn.__version__)
print("Optuna:", optuna.__version__)
print("XGBoost:", xgboost.__version__)
print("LightGBM:", lightgbm.__version__)
print("Tensorflow", tf.__version__)
# Out:
# Versão:
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Pandas: 2.2.2
# Numpy: 2.0.2
# Feature Engine: 1.8.0
# Scikit-Learn: 1.5.2
# Optuna: 4.8.0
# XGBoost: 3.2.0
# LightGBM: 4.6.0
# Tensorflow 2.20.0

# %%
SEED = 42
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

tf.random.set_seed(SEED)

torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Garante que as operações na GPU sejam determinísticas (pode reduzir sutilmente a performance)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
path_main = '/content/drive/MyDrive/ML-UFF'
# Out:
# Mounted at /content/drive

# %%
def get_data_frame(path_dataset: str):
  data = pd.read_csv(path_dataset)
  return data

# %%
path = f'{path_main}/df_feat.csv'
df = get_data_frame(path)

# %%
df['data'] = pd.to_datetime(df['data'])
df.set_index('data', inplace=True)

# %%
df.shape, df.columns
# Out:
# ((2245, 66),
#  Index(['total_casos', 'score_gravidade', 'idade', 'chuva_dia', 'temp_max_dia',
#         'temp_min_dia', 'umidade_dia', 'year', 'month', 'day_week',
#         'chuva_acum_7d', 'gravidade_lag_7d', 'chuva_acum_15d',
#         'gravidade_lag_15d', 'chuva_acum_21d', 'gravidade_lag_21d',
#         'chuva_acum_30d', 'gravidade_lag_30d', 'chuva_acum_45d',
#         'gravidade_lag_45d', 'chuva_acum_50d', 'gravidade_lag_50d',
#         'chuva_acum_60d', 'gravidade_lag_60d', 'casos_mm7d', 'casos_mm15d',
#         'casos_mm21d', 'casos_mm30d', 'casos_mm45d', 'casos_mm50d',
#         'casos_mm60d', 'temp_min_lag_7d', 'temp_min_lag_15d',
#         'temp_min_lag_21d', 'temp_min_lag_30d', 'temp_min_lag_45d',
#         'temp_min_lag_50d', 'temp_min_lag_60d', 'temp_max_lag_7d',
#         'temp_max_lag_15d', 'temp_max_lag_21d', 'temp_max_lag_30d',
#         'temp_max_lag_45d', 'temp_max_lag_50d', 'temp_max_lag_60d',
#         'faixa_chuva', 'faixa_umidade', 'day_month', 'day_month_start',
#         'day_month_end', 'day_quarter_start', 'day_quarter_end',
#         'day_year_start', 'day_year_end', 'ciclos_fourier_cos_p7_k1',
#         'ciclos_fourier_sin_p7_k1', 'ciclos_fourier_cos_p7_k2',
#         'ciclos_fourier_sin_p7_k2', 'ciclos_fourier_cos_p7_k3',
#         'ciclos_fourier_sin_p7_k3', 'ciclos_fourier_cos_p30_k1',
#         'ciclos_fourier_sin_p30_k1', 'ciclos_fourier_cos_p365_k1',
#         'ciclos_fourier_sin_p365_k1', 'ciclos_fourier_cos_p365_k2',
#         'ciclos_fourier_sin_p365_k2'],
#        dtype='object'))

# %%
def print_nan(df):
    nan_count = df.isna().sum()
    # Filtra apenas onde a contagem é maior que zero
    nan_only = nan_count[nan_count > 0].sort_values(ascending=False)

    if nan_only.empty:
        print("Nenhum valor NaN encontrado!")
    else:
        print("Colunas com valores NaN:")
        print(nan_only)

# %%
print_nan(df)
# Out:
# Nenhum valor NaN encontrado!

# %% [markdown]
# ### Train Test Split

# %%
# Separar o df
def train_test_split_by_date(
    data: pd.DataFrame | pd.Series,
    start_date: str,
    split_date: str,
    end_date: str | None = None,
):
    if not isinstance(data.index, pd.DatetimeIndex):
        raise ValueError("data must have a DatetimeIndex")

    # garantir ordem temporal
    data = data.sort_index()

    start_date = pd.to_datetime(start_date)
    split_date = pd.to_datetime(split_date)
    end_date = pd.to_datetime(end_date) if end_date else data.index.max()

    if not (start_date < split_date < end_date):
        raise ValueError("start_date < split_date < end_date is required")

    # 🔑 slicing robusto (não depende da data existir no índice)
    start_pos = data.index.searchsorted(start_date, side="left")
    end_pos = data.index.searchsorted(end_date, side="right")

    data = data.iloc[start_pos:end_pos]

    split_pos = data.index.searchsorted(split_date, side="right")
    train = data.iloc[:split_pos]
    test = data.iloc[split_pos:]

    return train, test

# %%
start_date = df.index.min().strftime('%Y-%m-%d')
split_date_test = '2025-12-24' # 60 dias maior lag gerado
split_date_validation = '2025-08-26' # 60 dias
end_date = df.index.max().strftime('%Y-%m-%d')

start_date, split_date_validation, split_date_test, end_date
# Out:
# ('2020-03-01', '2025-08-26', '2025-12-24', '2026-04-23')

# %%
df_train_temp, df_test = train_test_split_by_date(df, start_date, split_date_test, end_date)

# %%
df_train, df_val = train_test_split_by_date(df_train_temp, start_date, split_date_validation, split_date_test)

# %%
df_train.shape, df_train.index.unique()
# Out:
# ((2005, 66),
#  DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                 '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                 '2020-03-09', '2020-03-10',
#                 ...
#                 '2025-08-17', '2025-08-18', '2025-08-19', '2025-08-20',
#                 '2025-08-21', '2025-08-22', '2025-08-23', '2025-08-24',
#                 '2025-08-25', '2025-08-26'],
#                dtype='datetime64[ns]', name='data', length=2005, freq=None))

# %%
df_val.shape, df_val.index.unique()
# Out:
# ((120, 66),
#  DatetimeIndex(['2025-08-27', '2025-08-28', '2025-08-29', '2025-08-30',
#                 '2025-08-31', '2025-09-01', '2025-09-02', '2025-09-03',
#                 '2025-09-04', '2025-09-05',
#                 ...
#                 '2025-12-15', '2025-12-16', '2025-12-17', '2025-12-18',
#                 '2025-12-19', '2025-12-20', '2025-12-21', '2025-12-22',
#                 '2025-12-23', '2025-12-24'],
#                dtype='datetime64[ns]', name='data', length=120, freq=None))

# %%
df_test.shape, df_test.index.unique()
# Out:
# ((120, 66),
#  DatetimeIndex(['2025-12-25', '2025-12-26', '2025-12-27', '2025-12-28',
#                 '2025-12-29', '2025-12-30', '2025-12-31', '2026-01-01',
#                 '2026-01-02', '2026-01-03',
#                 ...
#                 '2026-04-14', '2026-04-15', '2026-04-16', '2026-04-17',
#                 '2026-04-18', '2026-04-19', '2026-04-20', '2026-04-21',
#                 '2026-04-22', '2026-04-23'],
#                dtype='datetime64[ns]', name='data', length=120, freq=None))

# %%
df_train.describe()
# Out:
#        total_casos  score_gravidade        idade    chuva_dia  temp_max_dia  \
# count  2005.000000      2005.000000  2005.000000  2005.000000   2005.000000
# mean     44.942643        11.634130    30.729394    11.804140     30.199594
# std     129.641138         0.274246     8.451706    33.359878      4.177824
# min       0.000000         9.000000     0.000000     0.000000     18.700000
# 25%       3.000000        11.517241    26.666667     0.000000     27.100000
# 50%      11.000000        11.625000    30.363636     0.200000     30.200000
# 75%      35.000000        11.765957    33.924781     6.200000     33.300000
# max    1501.000000        12.000000    68.000000   520.600000     42.500000
#
#        temp_min_dia  umidade_dia         year        month     day_week  ...  \
# count   2005.000000  2005.000000  2005.000000  2005.000000  2005.000000  ...
# mean      18.566284    78.124558  2022.415960     6.426434     2.999002  ...
# std        3.094147     7.382627     1.612868     3.344522     2.001745  ...
# min        8.300000    39.593750  2020.000000     1.000000     0.000000  ...
# 25%       16.400000    73.958333  2021.000000     4.000000     1.000000  ...
# 50%       19.000000    78.468750  2022.000000     6.000000     3.000000  ...
# 75%       21.000000    83.171875  2024.000000     9.000000     5.000000  ...
# max       25.400000    95.359375  2025.000000    12.000000     6.000000  ...
#
#        ciclos_fourier_cos_p7_k2  ciclos_fourier_sin_p7_k2  \
# count               2005.000000              2.005000e+03
# mean                  -0.000062              2.698475e-04
# std                    0.707411              7.071557e-01
# min                   -0.900969             -9.749279e-01
# 25%                   -0.900969             -7.818315e-01
# 50%                   -0.222521             -4.311252e-14
# 75%                    0.623490              7.818315e-01
# max                    1.000000              9.749279e-01
#
#        ciclos_fourier_cos_p7_k3  ciclos_fourier_sin_p7_k3  \
# count               2005.000000              2.005000e+03
# mean                   0.000360             -1.735400e-04
# std                    0.707530              7.070360e-01
# min                   -0.900969             -9.749279e-01
# 25%                   -0.900969             -7.818315e-01
# 50%                   -0.222521             -6.073010e-14
# 75%                    0.623490              7.818315e-01
# max                    1.000000              9.749279e-01
#
#        ciclos_fourier_cos_p30_k1  ciclos_fourier_sin_p30_k1  \
# count                2005.000000                2005.000000
# mean                   -0.001930                   0.001402
# std                     0.707053                   0.707509
# min                    -1.000000                  -0.994522
# 25%                    -0.669131                  -0.743145
# 50%                    -0.104528                   0.000000
# 75%                     0.669131                   0.743145
# max                     1.000000                   0.994522
#
#        ciclos_fourier_cos_p365_k1  ciclos_fourier_sin_p365_k1  \
# count                 2005.000000                 2005.000000
# mean                     0.001745                    0.057908
# std                      0.706841                    0.705349
# min                     -0.999963                   -0.999991
# 25%                     -0.708627                   -0.648630
# 50%                      0.004304                    0.128748
# 75%                      0.702527                    0.752667
# max                      1.000000                    0.999991
#
#        ciclos_fourier_cos_p365_k2  ciclos_fourier_sin_p365_k2
# count                 2005.000000                2.005000e+03
# mean                    -0.001244                7.505943e-05
# std                      0.706845                7.077203e-01
# min                     -0.999963               -9.999907e-01
# 25%                     -0.708627               -7.055836e-01
# 50%                      0.004304                2.572996e-15
# 75%                      0.702527                7.055836e-01
# max                      1.000000                9.999907e-01
#
# [8 rows x 64 columns]

# %%
df_val.describe()
# Out:
#        total_casos  score_gravidade       idade   chuva_dia  temp_max_dia  \
# count   120.000000       120.000000  120.000000  120.000000    120.000000
# mean      7.366667        11.573481   28.250134    8.280000     30.158333
# std       2.857787         0.179567    6.356627   18.324496      4.261762
# min       2.000000        11.142857   14.305556    0.000000     21.500000
# 25%       5.000000        11.500000   24.809524    0.000000     27.175000
# 50%       7.000000        11.563492   27.734848    0.200000     29.850000
# 75%       9.000000        11.675000   31.664773    8.200000     32.900000
# max      16.000000        12.000000   52.166667  134.400000     40.000000
#
#        temp_min_dia  umidade_dia    year       month    day_week  ...  \
# count    120.000000   120.000000   120.0  120.000000  120.000000  ...
# mean      18.225000    77.165972  2025.0   10.316667    2.991667  ...
# std        2.414426     8.187556     0.0    1.173828    2.002082  ...
# min       12.100000    51.916667  2025.0    8.000000    0.000000  ...
# 25%       16.825000    72.373698  2025.0    9.000000    1.000000  ...
# 50%       18.400000    78.645833  2025.0   10.000000    3.000000  ...
# 75%       19.825000    82.998698  2025.0   11.000000    5.000000  ...
# max       22.800000    95.046875  2025.0   12.000000    6.000000  ...
#
#        ciclos_fourier_cos_p7_k2  ciclos_fourier_sin_p7_k2  \
# count                120.000000              1.200000e+02
# mean                   0.005196             -6.515262e-03
# std                    0.709394              7.106995e-01
# min                   -0.900969             -9.749279e-01
# 25%                   -0.900969             -7.818315e-01
# 50%                   -0.222521             -1.724402e-13
# 75%                    0.623490              7.818315e-01
# max                    1.000000              9.749279e-01
#
#        ciclos_fourier_cos_p7_k3  ciclos_fourier_sin_p7_k3  \
# count                120.000000              1.200000e+02
# mean                  -0.001854              8.124399e-03
# std                    0.707398              7.126856e-01
# min                   -0.900969             -9.749279e-01
# 25%                   -0.900969             -7.818315e-01
# 50%                   -0.222521             -2.429798e-13
# 75%                    0.623490              7.818315e-01
# max                    1.000000              9.749279e-01
#
#        ciclos_fourier_cos_p30_k1  ciclos_fourier_sin_p30_k1  \
# count               1.200000e+02               1.200000e+02
# mean               -1.580911e-16              -2.914335e-17
# std                 7.100716e-01               7.100716e-01
# min                -1.000000e+00              -9.945219e-01
# 25%                -6.691306e-01              -7.431448e-01
# 50%                 5.342948e-15              -1.225080e-14
# 75%                 6.691306e-01               7.431448e-01
# max                 1.000000e+00               9.945219e-01
#
#        ciclos_fourier_cos_p365_k1  ciclos_fourier_sin_p365_k1  \
# count                  120.000000                  120.000000
# mean                    -0.462306                   -0.691084
# std                      0.454632                    0.323388
# min                     -0.999963                   -0.999991
# 25%                     -0.891957                   -0.966289
# 50%                     -0.555997                   -0.831140
# 75%                     -0.077384                   -0.452060
# max                      0.421101                    0.043022
#
#        ciclos_fourier_cos_p365_k2  ciclos_fourier_sin_p365_k2
# count                  120.000000                  120.000000
# mean                    -0.162612                    0.393777
# std                      0.741514                    0.524911
# min                     -0.999963                   -0.763889
# 25%                     -0.867432                    0.023667
# 50%                     -0.381633                    0.512367
# 75%                      0.591195                    0.868519
# max                      0.999852                    0.999991
#
# [8 rows x 64 columns]

# %%
df_test.describe()
# Out:
#        total_casos  score_gravidade       idade   chuva_dia  temp_max_dia  \
# count   120.000000       120.000000  120.000000  120.000000    120.000000
# mean     10.550000        11.592108   32.377215   23.183333     32.079583
# std       5.327667         0.223171    7.406475   38.192116      3.607849
# min       0.000000        11.000000   10.000000    0.000000     22.900000
# 25%       6.000000        11.491667   27.866667    0.000000     29.600000
# 50%      10.000000        11.600000   31.538462   10.000000     31.750000
# 75%      14.000000        11.750000   36.000000   27.800000     35.025000
# max      25.000000        12.000000   62.666667  210.400000     40.800000
#
#        temp_min_dia  umidade_dia         year       month  day_week  ...  \
# count    120.000000   120.000000   120.000000  120.000000     120.0  ...
# mean      21.496667    82.836634  2025.941667    2.966667       3.0  ...
# std        1.136184     8.548816     0.235355    2.496833       2.0  ...
# min       17.500000    56.947917  2025.000000    1.000000       0.0  ...
# 25%       21.100000    77.618490  2026.000000    1.000000       1.0  ...
# 50%       21.300000    84.578125  2026.000000    3.000000       3.0  ...
# 75%       22.300000    91.055990  2026.000000    3.250000       5.0  ...
# max       24.200000    96.015625  2026.000000   12.000000       6.0  ...
#
#        ciclos_fourier_cos_p7_k2  ciclos_fourier_sin_p7_k2  \
# count                120.000000              1.200000e+02
# mean                   0.005196              6.515262e-03
# std                    0.709394              7.106995e-01
# min                   -0.900969             -9.749279e-01
# 25%                   -0.900969             -7.818315e-01
# 50%                   -0.222521             -1.253939e-13
# 75%                    0.623490              7.818315e-01
# max                    1.000000              9.749279e-01
#
#        ciclos_fourier_cos_p7_k3  ciclos_fourier_sin_p7_k3  \
# count                120.000000              1.200000e+02
# mean                  -0.001854             -8.124399e-03
# std                    0.707398              7.126856e-01
# min                   -0.900969             -9.749279e-01
# 25%                   -0.900969             -7.818315e-01
# 50%                   -0.222521             -2.057332e-13
# 75%                    0.623490              7.818315e-01
# max                    1.000000              9.749279e-01
#
#        ciclos_fourier_cos_p30_k1  ciclos_fourier_sin_p30_k1  \
# count               1.200000e+02               1.200000e+02
# mean                2.368476e-16              -4.584296e-16
# std                 7.100716e-01               7.100716e-01
# min                -1.000000e+00              -9.945219e-01
# 25%                -6.691306e-01              -7.431448e-01
# 50%                 1.219858e-14              -5.390303e-15
# 75%                 6.691306e-01               7.431448e-01
# max                 1.000000e+00               9.945219e-01
#
#        ciclos_fourier_cos_p365_k1  ciclos_fourier_sin_p365_k1  \
# count                  120.000000                  120.000000
# mean                     0.827735                   -0.078603
# std                      0.155771                    0.535728
# min                      0.436651                   -0.899631
# 25%                      0.714673                   -0.570226
# 50%                      0.869589                   -0.094533
# 75%                      0.966848                    0.405414
# max                      1.000000                    0.801361
#
#        ciclos_fourier_cos_p365_k2  ciclos_fourier_sin_p365_k2
# count                  120.000000                  120.000000
# mean                     0.418417                   -0.080191
# std                      0.482546                    0.769756
# min                     -0.618671                   -0.999917
# 25%                      0.021516                   -0.866330
# 50%                      0.512371                   -0.188199
# 75%                      0.869589                    0.741139
# max                      1.000000                    0.999917
#
# [8 rows x 64 columns]

# %%
print(f"Validação: {df_val.index.min()} até {df_val.index.max()} (Tamanho: {len(df_val)})")
print(f"Teste: {df_test.index.min()} até {df_test.index.max()} (Tamanho: {len(df_test)})")
print("Val e Test são iguais?", df_val.equals(df_test))
# Out:
# Validação: 2025-08-27 00:00:00 até 2025-12-24 00:00:00 (Tamanho: 120)
# Teste: 2025-12-25 00:00:00 até 2026-04-23 00:00:00 (Tamanho: 120)
# Val e Test são iguais? False

# %% [markdown]
# ### Split

# %%
def split_target(df: pd.DataFrame, columns_target: str):
    y = df[columns_target]
    X = df.drop(columns=[columns_target])

    return X, y

# %%
column_target = 'total_casos'

# %%
X_train, y_train = split_target(df_train, column_target)
X_val, y_val = split_target(df_val, column_target)
X_test, y_test = split_target(df_test, column_target)

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
X_test.shape, y_test.shape
# Out:
# (2005, 65) (2005,)
# (120, 65) (120,)
# ((120, 65), (120,))

# %%
y_train.isna().sum().sum(), y_val.isna().sum().sum(), y_test.isna().sum().sum()
# Out:
# (np.int64(0), np.int64(0), np.int64(0))

# %%
X_train.index, X_val.index, X_test.index
# Out:
# (DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                 '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                 '2020-03-09', '2020-03-10',
#                 ...
#                 '2025-08-17', '2025-08-18', '2025-08-19', '2025-08-20',
#                 '2025-08-21', '2025-08-22', '2025-08-23', '2025-08-24',
#                 '2025-08-25', '2025-08-26'],
#                dtype='datetime64[ns]', name='data', length=2005, freq=None),
#  DatetimeIndex(['2025-08-27', '2025-08-28', '2025-08-29', '2025-08-30',
#                 '2025-08-31', '2025-09-01', '2025-09-02', '2025-09-03',
#                 '2025-09-04', '2025-09-05',
#                 ...
#                 '2025-12-15', '2025-12-16', '2025-12-17', '2025-12-18',
#                 '2025-12-19', '2025-12-20', '2025-12-21', '2025-12-22',
#                 '2025-12-23', '2025-12-24'],
#                dtype='datetime64[ns]', name='data', length=120, freq=None),
#  DatetimeIndex(['2025-12-25', '2025-12-26', '2025-12-27', '2025-12-28',
#                 '2025-12-29', '2025-12-30', '2025-12-31', '2026-01-01',
#                 '2026-01-02', '2026-01-03',
#                 ...
#                 '2026-04-14', '2026-04-15', '2026-04-16', '2026-04-17',
#                 '2026-04-18', '2026-04-19', '2026-04-20', '2026-04-21',
#                 '2026-04-22', '2026-04-23'],
#                dtype='datetime64[ns]', name='data', length=120, freq=None))

# %% [markdown]
# # Scaler

# %%
X_train.columns
# Out:
# Index(['score_gravidade', 'idade', 'chuva_dia', 'temp_max_dia', 'temp_min_dia',
#        'umidade_dia', 'year', 'month', 'day_week', 'chuva_acum_7d',
#        'gravidade_lag_7d', 'chuva_acum_15d', 'gravidade_lag_15d',
#        'chuva_acum_21d', 'gravidade_lag_21d', 'chuva_acum_30d',
#        'gravidade_lag_30d', 'chuva_acum_45d', 'gravidade_lag_45d',
#        'chuva_acum_50d', 'gravidade_lag_50d', 'chuva_acum_60d',
#        'gravidade_lag_60d', 'casos_mm7d', 'casos_mm15d', 'casos_mm21d',
#        'casos_mm30d', 'casos_mm45d', 'casos_mm50d', 'casos_mm60d',
#        'temp_min_lag_7d', 'temp_min_lag_15d', 'temp_min_lag_21d',
#        'temp_min_lag_30d', 'temp_min_lag_45d', 'temp_min_lag_50d',
#        'temp_min_lag_60d', 'temp_max_lag_7d', 'temp_max_lag_15d',
#        'temp_max_lag_21d', 'temp_max_lag_30d', 'temp_max_lag_45d',
#        'temp_max_lag_50d', 'temp_max_lag_60d', 'faixa_chuva', 'faixa_umidade',
#        'day_month', 'day_month_start', 'day_month_end', 'day_quarter_start',
#        'day_quarter_end', 'day_year_start', 'day_year_end',
#        'ciclos_fourier_cos_p7_k1', 'ciclos_fourier_sin_p7_k1',
#        'ciclos_fourier_cos_p7_k2', 'ciclos_fourier_sin_p7_k2',
#        'ciclos_fourier_cos_p7_k3', 'ciclos_fourier_sin_p7_k3',
#        'ciclos_fourier_cos_p30_k1', 'ciclos_fourier_sin_p30_k1',
#        'ciclos_fourier_cos_p365_k1', 'ciclos_fourier_sin_p365_k1',
#        'ciclos_fourier_cos_p365_k2', 'ciclos_fourier_sin_p365_k2'],
#       dtype='object')

# %%
fourier = X_train.filter(like='ciclo')
cols_fourier = fourier.columns.to_list()
cols_fourier
# Out:
# ['ciclos_fourier_cos_p7_k1',
#  'ciclos_fourier_sin_p7_k1',
#  'ciclos_fourier_cos_p7_k2',
#  'ciclos_fourier_sin_p7_k2',
#  'ciclos_fourier_cos_p7_k3',
#  'ciclos_fourier_sin_p7_k3',
#  'ciclos_fourier_cos_p30_k1',
#  'ciclos_fourier_sin_p30_k1',
#  'ciclos_fourier_cos_p365_k1',
#  'ciclos_fourier_sin_p365_k1',
#  'ciclos_fourier_cos_p365_k2',
#  'ciclos_fourier_sin_p365_k2']

# %%
X_train_fourier = X_train[cols_fourier]
X_val_fourier = X_val[cols_fourier]
X_test_fourier = X_test[cols_fourier]
X_test_fourier
# Out:
#             ciclos_fourier_cos_p7_k1  ciclos_fourier_sin_p7_k1  \
# data
# 2025-12-25                 -0.900969             -4.338837e-01
# 2025-12-26                 -0.222521             -9.749279e-01
# 2025-12-27                  0.623490             -7.818315e-01
# 2025-12-28                  1.000000              3.922831e-14
# 2025-12-29                  0.623490              7.818315e-01
# ...                              ...                       ...
# 2026-04-19                  1.000000             -7.837740e-14
# 2026-04-20                  0.623490              7.818315e-01
# 2026-04-21                 -0.222521              9.749279e-01
# 2026-04-22                 -0.900969              4.338837e-01
# 2026-04-23                 -0.900969             -4.338837e-01
#
#             ciclos_fourier_cos_p7_k2  ciclos_fourier_sin_p7_k2  \
# data
# 2025-12-25                  0.623490              7.818315e-01
# 2025-12-26                 -0.900969              4.338837e-01
# 2025-12-27                 -0.222521             -9.749279e-01
# 2025-12-28                  1.000000              7.845662e-14
# 2025-12-29                 -0.222521              9.749279e-01
# ...                              ...                       ...
# 2026-04-19                  1.000000             -1.567548e-13
# 2026-04-20                 -0.222521              9.749279e-01
# 2026-04-21                 -0.900969             -4.338837e-01
# 2026-04-22                  0.623490             -7.818315e-01
# 2026-04-23                  0.623490              7.818315e-01
#
#             ciclos_fourier_cos_p7_k3  ciclos_fourier_sin_p7_k3  \
# data
# 2025-12-25                 -0.222521             -9.749279e-01
# 2025-12-26                  0.623490              7.818315e-01
# 2025-12-27                 -0.900969             -4.338837e-01
# 2025-12-28                  1.000000             -5.644361e-13
# 2025-12-29                 -0.900969              4.338837e-01
# ...                              ...                       ...
# 2026-04-19                  1.000000              2.196152e-13
# 2026-04-20                 -0.900969              4.338837e-01
# 2026-04-21                  0.623490             -7.818315e-01
# 2026-04-22                 -0.222521              9.749279e-01
# 2026-04-23                 -0.222521             -9.749279e-01
#
#             ciclos_fourier_cos_p30_k1  ciclos_fourier_sin_p30_k1  \
# data
# 2025-12-25                   0.500000                  -0.866025
# 2025-12-26                   0.669131                  -0.743145
# 2025-12-27                   0.809017                  -0.587785
# 2025-12-28                   0.913545                  -0.406737
# 2025-12-29                   0.978148                  -0.207912
# ...                               ...                        ...
# 2026-04-19                  -0.500000                  -0.866025
# 2026-04-20                  -0.309017                  -0.951057
# 2026-04-21                  -0.104528                  -0.994522
# 2026-04-22                   0.104528                  -0.994522
# 2026-04-23                   0.309017                  -0.951057
#
#             ciclos_fourier_cos_p365_k1  ciclos_fourier_sin_p365_k1  \
# data
# 2025-12-25                    0.436651                   -0.899631
# 2025-12-26                    0.452072                   -0.891981
# 2025-12-27                    0.467359                   -0.884068
# 2025-12-28                    0.482508                   -0.875892
# 2025-12-29                    0.497513                   -0.867456
# ...                                ...                         ...
# 2026-04-19                    0.651899                    0.758306
# 2026-04-20                    0.638749                    0.769415
# 2026-04-21                    0.625411                    0.780296
# 2026-04-22                    0.611886                    0.790946
# 2026-04-23                    0.598181                    0.801361
#
#             ciclos_fourier_cos_p365_k2  ciclos_fourier_sin_p365_k2
# data
# 2025-12-25                   -0.618671                   -0.785650
# 2025-12-26                   -0.591261                   -0.806480
# 2025-12-27                   -0.563151                   -0.826354
# 2025-12-28                   -0.534373                   -0.845249
# 2025-12-29                   -0.504961                   -0.863142
# ...                                ...                         ...
# 2026-04-19                   -0.150055                    0.988678
# 2026-04-20                   -0.183998                    0.982927
# 2026-04-21                   -0.217723                    0.976011
# 2026-04-22                   -0.251190                    0.967938
# 2026-04-23                   -0.284359                    0.958718
#
# [120 rows x 12 columns]

# %%
X_train_s = X_train.drop(columns=cols_fourier)
X_val_s = X_val.drop(columns=cols_fourier)
X_test_s = X_test.drop(columns=cols_fourier)

# %%
X_train_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2005 entries, 2020-03-01 to 2025-08-26
# Data columns (total 53 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   score_gravidade    2005 non-null   float64
#  1   idade              2005 non-null   float64
#  2   chuva_dia          2005 non-null   float64
#  3   temp_max_dia       2005 non-null   float64
#  4   temp_min_dia       2005 non-null   float64
#  5   umidade_dia        2005 non-null   float64
#  6   year               2005 non-null   int64
#  7   month              2005 non-null   int64
#  8   day_week           2005 non-null   int64
#  9   chuva_acum_7d      2005 non-null   float64
#  10  gravidade_lag_7d   2005 non-null   float64
#  11  chuva_acum_15d     2005 non-null   float64
#  12  gravidade_lag_15d  2005 non-null   float64
#  13  chuva_acum_21d     2005 non-null   float64
#  14  gravidade_lag_21d  2005 non-null   float64
#  15  chuva_acum_30d     2005 non-null   float64
#  16  gravidade_lag_30d  2005 non-null   float64
#  17  chuva_acum_45d     2005 non-null   float64
#  18  gravidade_lag_45d  2005 non-null   float64
#  19  chuva_acum_50d     2005 non-null   float64
#  20  gravidade_lag_50d  2005 non-null   float64
#  21  chuva_acum_60d     2005 non-null   float64
#  22  gravidade_lag_60d  2005 non-null   float64
#  23  casos_mm7d         2005 non-null   float64
#  24  casos_mm15d        2005 non-null   float64
#  25  casos_mm21d        2005 non-null   float64
#  26  casos_mm30d        2005 non-null   float64
#  27  casos_mm45d        2005 non-null   float64
#  28  casos_mm50d        2005 non-null   float64
#  29  casos_mm60d        2005 non-null   float64
#  30  temp_min_lag_7d    2005 non-null   float64
#  31  temp_min_lag_15d   2005 non-null   float64
#  32  temp_min_lag_21d   2005 non-null   float64
#  33  temp_min_lag_30d   2005 non-null   float64
#  34  temp_min_lag_45d   2005 non-null   float64
#  35  temp_min_lag_50d   2005 non-null   float64
#  36  temp_min_lag_60d   2005 non-null   float64
#  37  temp_max_lag_7d    2005 non-null   float64
#  38  temp_max_lag_15d   2005 non-null   float64
#  39  temp_max_lag_21d   2005 non-null   float64
#  40  temp_max_lag_30d   2005 non-null   float64
#  41  temp_max_lag_45d   2005 non-null   float64
#  42  temp_max_lag_50d   2005 non-null   float64
#  43  temp_max_lag_60d   2005 non-null   float64
#  44  faixa_chuva        2005 non-null   object
#  45  faixa_umidade      2005 non-null   object
#  46  day_month          2005 non-null   int64
#  47  day_month_start    2005 non-null   int64
#  48  day_month_end      2005 non-null   int64
#  49  day_quarter_start  2005 non-null   int64
#  50  day_quarter_end    2005 non-null   int64
#  51  day_year_start     2005 non-null   int64
#  52  day_year_end       2005 non-null   int64
# dtypes: float64(41), int64(10), object(2)
# memory usage: 845.9+ KB

# %%
def encode_categorical_columns(df):
    df_encoded = df.copy()
    cat_cols = df_encoded.select_dtypes(include=['category', 'object']).columns

    for col in cat_cols:
        print(f"Transformando a coluna: {col}")
        df_encoded[col] = df_encoded[col].astype('category').cat.codes

    return df_encoded

# %%
X_train_s = encode_categorical_columns(X_train_s)
X_val_s = encode_categorical_columns(X_val_s)
X_test_s = encode_categorical_columns(X_test_s)
# Out:
# Transformando a coluna: faixa_chuva
# Transformando a coluna: faixa_umidade
# Transformando a coluna: faixa_chuva
# Transformando a coluna: faixa_umidade
# Transformando a coluna: faixa_chuva
# Transformando a coluna: faixa_umidade

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train_s)
X_val_scaled = scaler.transform(X_val_s)
X_test_scaled = scaler.transform(X_test_s)

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled,
                                 columns=X_train_s.columns,
                                 index=X_train_s.index)

X_val_scaled_df = pd.DataFrame(X_val_scaled,
                                 columns=X_val_s.columns,
                                 index=X_val_s.index)

X_test_scaled_df = pd.DataFrame(X_test_scaled,
                                 columns=X_test_s.columns,
                                 index=X_test_s.index)

X_train_scaled_df
# Out:
#             score_gravidade     idade  chuva_dia  temp_max_dia  temp_min_dia  \
# data
# 2020-03-01         0.813390 -0.441369  15.255535     -1.436415      0.883732
# 2020-03-02         0.118672  0.071475   1.403109     -1.460357      0.334171
# 2020-03-03         0.773310  0.059337   0.029859     -0.550566      0.431152
# 2020-03-04        -0.124480 -1.104123  -0.263980     -0.694217      0.786751
# 2020-03-05         0.339718  0.128857  -0.233996     -0.311147     -0.312372
# ...                     ...       ...        ...           ...           ...
# 2025-08-22         0.929176 -0.721900  -0.353931      0.598644     -0.829607
# 2025-08-23        -1.097085  0.515284  -0.353931      1.125366     -1.088224
# 2025-08-24        -0.286581 -0.572868  -0.353931     -0.311147     -0.635644
# 2025-08-25        -0.749726 -0.601986  -0.353931     -0.287205      0.528134
# 2025-08-26         0.422611 -0.027149  -0.245990     -1.077287      0.366498
#
#             umidade_dia      year     month  day_week  chuva_acum_7d  ...  \
# data                                                                  ...
# 2020-03-01     1.937805 -1.498302 -1.024747  1.499564       4.710811  ...
# 2020-03-02     1.731752 -1.498302 -1.024747 -1.498567       5.221635  ...
# 2020-03-03     0.932944 -1.498302 -1.024747 -0.998879       5.287261  ...
# 2020-03-04     0.615396 -1.498302 -1.024747 -0.499190       5.281940  ...
# 2020-03-05     0.175064 -1.498302 -1.024747  0.000498       4.840291  ...
# ...                 ...       ...       ...       ...            ...  ...
# 2025-08-22    -0.166476  1.602540  0.470608  0.500187      -0.713138  ...
# 2025-08-23    -2.856456  1.602540  0.470608  0.999876      -0.734422  ...
# 2025-08-24    -0.558824  1.602540  0.470608  1.499564      -0.734422  ...
# 2025-08-25     0.966816  1.602540  0.470608 -1.498567      -0.734422  ...
# 2025-08-26     1.761390  1.602540  0.470608 -0.998879      -0.702496  ...
#
#             temp_max_lag_60d  faixa_chuva  faixa_umidade  day_month  \
# data
# 2020-03-01          1.742544     0.499203      -1.369086  -1.672869
# 2020-03-02          0.488740     0.499203      -1.369086  -1.559105
# 2020-03-03         -0.282832     0.499203      -1.369086  -1.445341
# 2020-03-04         -0.186385     0.499203       1.338922  -1.331577
# 2020-03-05         -0.138162     0.499203       1.338922  -1.217813
# ...                      ...          ...            ...        ...
# 2025-08-22          0.874526    -0.392072      -0.466417   0.716174
# 2025-08-23         -1.006180    -0.392072       0.436253   0.829938
# 2025-08-24         -1.850087    -0.392072      -0.466417   0.943702
# 2025-08-25         -0.162274    -0.392072      -1.369086   1.057465
# 2025-08-26          0.078843    -0.392072      -1.369086   1.171229
#
#             day_month_start  day_month_end  day_quarter_start  \
# data
# 2020-03-01         5.420220      -0.183044          -0.105329
# 2020-03-02        -0.184494      -0.183044          -0.105329
# 2020-03-03        -0.184494      -0.183044          -0.105329
# 2020-03-04        -0.184494      -0.183044          -0.105329
# 2020-03-05        -0.184494      -0.183044          -0.105329
# ...                     ...            ...                ...
# 2025-08-22        -0.184494      -0.183044          -0.105329
# 2025-08-23        -0.184494      -0.183044          -0.105329
# 2025-08-24        -0.184494      -0.183044          -0.105329
# 2025-08-25        -0.184494      -0.183044          -0.105329
# 2025-08-26        -0.184494      -0.183044          -0.105329
#
#             day_quarter_end  day_year_start  day_year_end
# data
# 2020-03-01        -0.105329           -0.05         -0.05
# 2020-03-02        -0.105329           -0.05         -0.05
# 2020-03-03        -0.105329           -0.05         -0.05
# 2020-03-04        -0.105329           -0.05         -0.05
# 2020-03-05        -0.105329           -0.05         -0.05
# ...                     ...             ...           ...
# 2025-08-22        -0.105329           -0.05         -0.05
# 2025-08-23        -0.105329           -0.05         -0.05
# 2025-08-24        -0.105329           -0.05         -0.05
# 2025-08-25        -0.105329           -0.05         -0.05
# 2025-08-26        -0.105329           -0.05         -0.05
#
# [2005 rows x 53 columns]

# %%
X_train_scaled = pd.concat([X_train_scaled_df, X_train_fourier], axis=1)
X_val_scaled = pd.concat([X_val_scaled_df, X_val_fourier], axis=1)
X_test_scaled = pd.concat([X_test_scaled_df, X_test_fourier], axis=1)

# %%
X_train_scaled.shape, X_train.shape
# Out:
# ((2005, 65), (2005, 65))

# %%
X_val_scaled.shape, X_val.shape
# Out:
# ((120, 65), (120, 65))

# %%
X_test_scaled.shape, X_test.shape
# Out:
# ((120, 65), (120, 65))

# %%
X_test_scaled.head()
# Out:
#             score_gravidade     idade  chuva_dia  temp_max_dia  temp_min_dia  \
# data
# 2025-12-25        -0.124480  0.387072  -0.353931      2.106983      1.110023
# 2025-12-26        -0.749726 -0.397693  -0.353931      1.771796      0.883732
# 2025-12-27         1.334428  0.742119  -0.353931      1.269017      0.754424
# 2025-12-28        -0.124480  0.718449  -0.353931      1.556319      1.142350
# 2025-12-29        -2.312842 -1.743206  -0.353931      1.292959      0.819078
#
#             umidade_dia     year     month  day_week  chuva_acum_7d  ...  \
# data                                                                 ...
# 2025-12-25    -1.153696  1.60254  1.666892  0.000498      -0.562374  ...
# 2025-12-26    -0.496726  1.60254  1.666892  0.500187      -0.729101  ...
# 2025-12-27    -0.253978  1.60254  1.666892  0.999876      -0.734422  ...
# 2025-12-28    -0.776167  1.60254  1.666892  1.499564      -0.734422  ...
# 2025-12-29    -0.641386  1.60254  1.666892 -1.498567      -0.734422  ...
#
#             ciclos_fourier_cos_p7_k2  ciclos_fourier_sin_p7_k2  \
# data
# 2025-12-25                  0.623490              7.818315e-01
# 2025-12-26                 -0.900969              4.338837e-01
# 2025-12-27                 -0.222521             -9.749279e-01
# 2025-12-28                  1.000000              7.845662e-14
# 2025-12-29                 -0.222521              9.749279e-01
#
#             ciclos_fourier_cos_p7_k3  ciclos_fourier_sin_p7_k3  \
# data
# 2025-12-25                 -0.222521             -9.749279e-01
# 2025-12-26                  0.623490              7.818315e-01
# 2025-12-27                 -0.900969             -4.338837e-01
# 2025-12-28                  1.000000             -5.644361e-13
# 2025-12-29                 -0.900969              4.338837e-01
#
#             ciclos_fourier_cos_p30_k1  ciclos_fourier_sin_p30_k1  \
# data
# 2025-12-25                   0.500000                  -0.866025
# 2025-12-26                   0.669131                  -0.743145
# 2025-12-27                   0.809017                  -0.587785
# 2025-12-28                   0.913545                  -0.406737
# 2025-12-29                   0.978148                  -0.207912
#
#             ciclos_fourier_cos_p365_k1  ciclos_fourier_sin_p365_k1  \
# data
# 2025-12-25                    0.436651                   -0.899631
# 2025-12-26                    0.452072                   -0.891981
# 2025-12-27                    0.467359                   -0.884068
# 2025-12-28                    0.482508                   -0.875892
# 2025-12-29                    0.497513                   -0.867456
#
#             ciclos_fourier_cos_p365_k2  ciclos_fourier_sin_p365_k2
# data
# 2025-12-25                   -0.618671                   -0.785650
# 2025-12-26                   -0.591261                   -0.806480
# 2025-12-27                   -0.563151                   -0.826354
# 2025-12-28                   -0.534373                   -0.845249
# 2025-12-29                   -0.504961                   -0.863142
#
# [5 rows x 65 columns]

# %%
print_nan(X_train_scaled)
print_nan(X_val_scaled)
print_nan(X_test_scaled)
# Out:
# Nenhum valor NaN encontrado!
# Nenhum valor NaN encontrado!
# Nenhum valor NaN encontrado!

# %% [markdown]
# # Metrics/Results

# %%
df_result = pd.DataFrame()

# %%
def get_erros_metric(y_test, predict, time):
    # Criamos um NOVO dicionário aqui dentro, sem depender de variável global
    metrics = {
        'Start': y_test.index.min(),
        'End': y_test.index.max(),
        'MAE': mean_absolute_error(y_test, predict),
        'MSE': mean_squared_error(y_test, predict),
        'RMSE': np.sqrt(mean_squared_error(y_test, predict)),
        'R2': r2_score(y_test, predict),
        'Seconds': round(time, 6)
    }
    return metrics

# %%
def add_resultado(df_result: pd.DataFrame, forecast_method: str, method_metrics: dict) -> pd.DataFrame:
    # Se ainda não tem coluna 'Type', cria
    if "Type" not in df_result.columns:
        df_result = pd.DataFrame(columns=["Type"])

    mask = df_result["Type"] == forecast_method

    if mask.any():
        for key, value in method_metrics.items():
            df_result.loc[mask, key] = value
    else:
        new_row = {"Type": forecast_method}
        new_row.update(method_metrics)
        df_result = pd.concat([df_result, pd.DataFrame([new_row])], ignore_index=True)

    return df_result

# %% [markdown]
# # LSTM

# %%
model_name = 'LSTM'

# %%
import tensorflow.compat.v2 as tf

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Input, LSTM, GRU, Dense, Dropout,
                                     BatchNormalization, Bidirectional,
                                     Add, Attention, GlobalAveragePooling1D, Concatenate)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from tensorflow.keras.layers import LSTM, Bidirectional, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber

# %%
tf.keras.backend.clear_session()

# %%
#from sklearn.model_selection import TimeSeriesSplit

def lstm_model(X_train_lstm):
    # Entrada de dados
    inputs = Input(shape=(X_train_lstm.shape[1], X_train_lstm.shape[2]))

    # Camada de projeção inicial para enriquecer as features de entrada
    init_projection = Dense(64, activation='gelu')(inputs)

    # --- BLOCO RECORRENTE 1 ---
    x1 = Bidirectional(LSTM(128, activation='tanh', return_sequences=True))(init_projection)
    x1 = BatchNormalization()(x1)
    x1 = Dropout(0.25)(x1)

    # --- BLOCO RECORRENTE 2 ---
    x2 = Bidirectional(GRU(64, activation='tanh', return_sequences=True))(x1)
    x2 = BatchNormalization()(x2)
    x2 = Dropout(0.25)(x2)

    # --- BLOCO RECORRENTE 3 (Residual) ---
    x3 = Bidirectional(LSTM(64, activation='tanh', return_sequences=True))(x2)
    x3 = BatchNormalization()(x3)

    # Conexão residual entre o bloco 2 e 3
    res_1 = Add()([x2, x3])
    res_1 = Dropout(0.3)(res_1)

    # --- MECANISMO DE ATENÇÃO (O grande diferencial) ---
    # O modelo aprende a dar pesos diferentes para momentos diferentes do passado
    query = LSTM(128, activation='tanh', return_sequences=True)(res_1)
    attn_output = Attention(dropout=0.2)([query, res_1])

    # Concatenamos o contexto da atenção com a sequência original processada
    context = Concatenate()([query, attn_output])

    # --- REDUÇÃO TEMPORAL INTELIGENTE ---
    # Em vez de pegar apenas o último estado, combinamos a compressão do LSTM com a média global
    x4 = LSTM(64, activation='tanh', return_sequences=False)(context)
    x4_pool = GlobalAveragePooling1D()(context)

    # Fusão final das características temporais
    merged = Concatenate()([x4, x4_pool])
    merged = BatchNormalization()(merged)
    merged = Dropout(0.3)(merged)

    # --- CABEÇA DE REGRESSÃO DE ALTA CAPACIDADE ---
    dense1 = Dense(64, activation='gelu')(merged)
    dense1 = BatchNormalization()(dense1)
    dense1 = Dropout(0.2)(dense1)

    dense2 = Dense(16, activation='gelu')(dense1)
    dense2 = BatchNormalization()(dense2)

    outputs = Dense(1)(dense2)

    # Construção do modelo
    model = Model(inputs=inputs, outputs=outputs)

    # --- OTIMIZAÇÃO AVANÇADA ---
    # AMSGrad ajuda o Adam a convergir melhor em vales difíceis de perda
    optimizer = Adam(learning_rate=0.001, amsgrad=True)
    model.compile(optimizer=optimizer, loss=Huber(delta=1.3)) # Aumentado levemente o delta para dar foco a grandes tendências

    return model

# %%
# Nunca use o mesmo objeto scaler que você usou para o X
scaler_y = StandardScaler()

# %%
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_val_scaled  = scaler_y.transform(y_val.values.reshape(-1, 1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1, 1))

# %%
X_train_scaled_np = X_train_scaled.values  # converte para NumPy array
X_val_scaled_np  = X_val_scaled.values
X_test_scaled_np  = X_test_scaled.values

# %%
# --- Remodelar para LSTM ---
X_train_lstm = X_train_scaled_np.reshape((X_train_scaled_np.shape[0], 1, X_train_scaled_np.shape[1]))
X_val_lstm  = X_val_scaled_np.reshape((X_val_scaled_np.shape[0], 1, X_val_scaled_np.shape[1]))
X_test_lstm  = X_test_scaled_np.reshape((X_test_scaled_np.shape[0], 1, X_test_scaled_np.shape[1]))

# %% [markdown]
# #### Feature Selection

# %%
# model_lstm_feat = lstm_model(X_train_lstm)

# %%
# Feature Selection
# def lstm_permutation_feature_selection(model, X_val, y_val, feature_names, metric_fn=mean_squared_error):
#     baseline_preds = model.predict(X_val, verbose=0)
#     baseline_error = metric_fn(y_val, baseline_preds)
#     print(f"Erro Base (Baseline): {baseline_error:.5f}\n")

#     feature_importances = {}
#     num_features = X_val.shape[2]
#     num_samples = X_val.shape[0]

#     for i in range(num_features):
#         feature_name = feature_names[i]
#         X_val_permuted = X_val.copy()

#         # Correção segura para o embaralhamento:
#         # Criamos um vetor de índices embaralhados
#         idx = np.random.permutation(num_samples)

#         # Substituímos a feature 'i' (em todos os timesteps) pela sua versão embaralhada
#         X_val_permuted[:, :, i] = X_val_permuted[idx, :, i]

#         permuted_preds = model.predict(X_val_permuted, verbose=0)
#         permuted_error = metric_fn(y_val, permuted_preds)

#         importance = permuted_error - baseline_error
#         feature_importances[feature_name] = max(0, importance)

#         print(f"Feature: {feature_name} | Erro pós-permutação: {permuted_error:.5f} | Impacto: {importance:.5f}")

#     sorted_importances = dict(sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))
#     return sorted_importances

# %%
# # Treine seu modelo LSTM normalmente
# model_lstm_feat.fit(X_train_lstm, y_train_scaled, validation_data=(X_val_lstm, y_val_scaled), epochs=10, batch_size=32)

# # 3. Rode a função de seleção
# importancia_features = lstm_permutation_feature_selection(
#     model=model_lstm_feat,
#     X_val=X_val_lstm,
#     y_val=y_val_scaled,
#     feature_names=X_train.columns.to_list()
# )

# # --- CRITÉRIO DE CORTE ---
# # Opção A: Filtrar por Limiar (vamos manter apenas quem teve impacto maior que 0.0001)
# limiar = 0.0001
# features_selecionadas = [feat for feat, imp in importancia_features.items() if imp > limiar]

# # Visualize o resultado e decida o corte
# print("\n--- RANKING FINAL DE IMPORTÂNCIA ---")
# for feat, imp in importancia_features.items():
#     # Se a feature passou pelo corte, colocamos um indicador [SELECIONADA]
#     status = "[SELECIONADA]" if feat in features_selecionadas else "[ELIMINADA]"
#     print(f"{feat}: {imp:.5f} -> {status}")

# print(f"\nTotal de features selecionadas: {len(features_selecionadas)}")

# %%
# # 1. Configurar o estilo e tamanho do gráfico (largura maior para caber os nomes)
# plt.figure(figsize=(12, 6))
# sns.set_theme(style="whitegrid")

# # 2. Extrair os nomes e os valores do dicionário
# nomes_plot = list(importancia_features.keys())
# valores_plot = list(importancia_features.values())

# # 3. Criar o gráfico de barras verticais
# # Invertemos x e y aqui. O 'Blues_r' faz as barras mais importantes ficarem mais escuras
# ax = sns.barplot(x=nomes_plot, y=valores_plot, palette="Blues_r")

# # 4. Adicionar uma linha HORIZONTAL indicando o corte (limiar)
# # limiar = 0.0001  # O mesmo limiar que você definiu antes
# plt.axhline(y=limiar, color='red', linestyle='--', linewidth=1.5, label=f'Limiar de Corte ({limiar})')

# # 5. Customizar títulos e labels
# plt.title('Importância das Features por Permutação (Modelo LSTM)', fontsize=14, fontweight='bold', pad=15)
# plt.xlabel('Features', fontsize=12)
# plt.ylabel('Aumento no Erro', fontsize=12)
# plt.legend(loc='upper right')

# # O TRUQUE DE OURO: Rotacionar os nomes no eixo X para eles não se atropelarem
# plt.xticks(rotation=90, ha='right', fontsize=10)

# # Ajusta o layout para garantir que os nomes rotacionados não sejam cortados
# plt.tight_layout()

# # 6. Exibir o gráfico
# plt.show()

# %%
# len(features_selecionadas), len(X_train.columns)

# %%
# X_train_sel = X_train_scaled[features_selecionadas]
# X_val_sel = X_val_scaled[features_selecionadas]
# X_test_sel  = X_test_scaled[features_selecionadas]

# %%
# X_train_sel.info()

# %%
# scaler_y_novo = StandardScaler() # Substitua pelo seu scaler (MinMaxScaler, etc)

# X_train_scaled_np = scaler_y_novo.fit_transform(X_train_sel)
# X_val_scaled_np   = scaler_y_novo.transform(X_val_sel)
# X_test_scaled_np  = scaler_y_novo.transform(X_test_sel)

# %%
# y_train_scaled = scaler_y_novo.fit_transform(y_train.values.reshape(-1, 1))
# y_val_scaled  = scaler_y_novo.transform(y_val.values.reshape(-1, 1))
# y_test_scaled  = scaler_y_novo.transform(y_test.values.reshape(-1, 1))

# %%
# # Faz o Reshape para o formato da LSTM (amostras, timesteps, features)
# # Note que agora o shape[1] refletirá apenas a quantidade de features selecionadas
# X_train_lstm = X_train_scaled_np.reshape((X_train_scaled_np.shape[0], 1, X_train_scaled_np.shape[1]))
# X_val_lstm   = X_val_scaled_np.reshape((X_val_scaled_np.shape[0], 1, X_val_scaled_np.shape[1]))
# X_test_lstm  = X_test_scaled_np.reshape((X_test_scaled_np.shape[0], 1, X_test_scaled_np.shape[1]))

# %% [markdown]
# #### Model

# %%
model_lstm_val = lstm_model(X_train_lstm)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,      # Reduz a taxa de aprendizado pela metade
    patience=7,      # Se por 5 épocas o erro não cair
    min_lr=1e-6,     # Limite mínimo
    verbose=1
)

# %%
callbacks = [early_stop, reduce_lr]

# %%
start_time = time.time()
history = model_lstm_val.fit(
    X_train_lstm, y_train_scaled,
    # validation_split=0.2, já fiz o split do train e val
    validation_data=(X_val_lstm, y_val_scaled),
    epochs=500,
    batch_size=32, # Se o modelo for muito grande, tente aumentar para 64 para estabilizar o gradiente
    verbose=1,
    callbacks=callbacks
)
end_time = time.time()
# Out:
# Epoch 1/500
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 41ms/step - loss: 0.3702 - val_loss: 0.0250 - learning_rate: 0.0010
# Epoch 2/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2192 - val_loss: 0.0290 - learning_rate: 0.0010
# Epoch 3/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1761 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 4/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.1607 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 5/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1524 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 6/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1444 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 7/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1405 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 8/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1301 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 9/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1329 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 10/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1232 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 11/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1202 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 12/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1219 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 13/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1226 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 14/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1149 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 15/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1128 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 16/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1084 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 17/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1117 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 18/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1083 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 19/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1016 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 20/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1033 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 21/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1074 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 22/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1020 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 23/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0933 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 24/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0945 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 25/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1070 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 26/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0943 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 27/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1022 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 28/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0923 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 29/500
# 60/63 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1079
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1024 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 30/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0902 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 31/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0838 - val_loss: 0.0030 - learning_rate: 5.0000e-04
# Epoch 32/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0821 - val_loss: 0.0037 - learning_rate: 5.0000e-04
# Epoch 33/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0766 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 34/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0726 - val_loss: 0.0027 - learning_rate: 5.0000e-04
# Epoch 35/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0744 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 36/500
# 61/63 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0764
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0699 - val_loss: 0.0024 - learning_rate: 5.0000e-04
# Epoch 37/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0718 - val_loss: 0.0029 - learning_rate: 2.5000e-04

# %%
y_pred_val_scaled = model_lstm_val.predict(X_val_lstm)
y_pred_val_lstm = scaler_y.inverse_transform(y_pred_val_scaled)
# y_pred_val_lstm = scaler_y_novo.inverse_transform(y_pred_val_scaled)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 417ms/step

# %%
y_pred_val_lstm_ = pd.DataFrame(y_pred_val_lstm, columns=[column_target], index=y_val.index)

# %%
plt.figure(figsize=(12,5))
plt.plot(y_val.index, y_val, label='Real',  color='green', lw=2)
plt.plot(y_val.index, y_pred_val_lstm_, label='Previsto', color='orange', lw=2)
plt.title(f"{model_name} Previsão vs Real (Validação)")
plt.xlabel("Date")
plt.ylabel("Total de Casos")
plt.legend()
plt.show()

# %%
metrics_ = dict()
metrics_ = get_erros_metric(y_val, y_pred_val_lstm_, (end_time - start_time))
df_result = add_resultado(df_result, f'{model_name}_val', metrics_)
df_result
# Out:
#        Type      Start        End      MAE        MSE      RMSE        R2  \
# 0  LSTM_val 2025-08-27 2025-12-24  6.79134  75.001892  8.660363 -8.260763
#
#      Seconds
# 0  86.121819

# %%
y_pred_test_scaled = model_lstm_val.predict(X_test_lstm)
y_pred_test_lstm = scaler_y.inverse_transform(y_pred_test_scaled)
# y_pred_test_lstm = scaler_y_novo.inverse_transform(y_pred_test_scaled)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
y_pred_test_lstm_ = pd.DataFrame(y_pred_test_lstm, columns=[column_target], index=y_test.index)

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test.index, y_test, label='Real',  color='green', lw=2)
plt.plot(y_test.index, y_pred_test_lstm_, label='Previsto', color='orange', lw=2)
plt.title(f"{model_name} Previsão vs Real (Test)")
plt.xlabel("Date")
plt.ylabel("Total de Casos")
plt.legend()
plt.show()

# %%
metrics_ = dict()
metrics_ = get_erros_metric(y_test, y_pred_test_lstm_, (end_time - start_time))
df_result = add_resultado(df_result, f'{model_name}_test', metrics_)
df_result
# Out:
#         Type      Start        End       MAE         MSE       RMSE        R2  \
# 0   LSTM_val 2025-08-27 2025-12-24  6.791340   75.001892   8.660363 -8.260763
# 1  LSTM_test 2025-12-25 2026-04-23  9.783911  192.986719  13.891966 -5.856265
#
#      Seconds
# 0  86.121819
# 1  86.121819

# %%
# Train + Val
# 1. Unir os dados de Treino e Validação (X e y já escalonados)
X_final_train = np.concatenate((X_train_lstm, X_val_lstm), axis=0)
y_final_train = np.concatenate((y_train_scaled, y_val_scaled), axis=0)

# %%
best_epoch = np.argmin(history.history['val_loss']) + 1


# Ajuste do número de épocas (Fator de desconto)
# Se a melhor época foi 50, ele treinará por 40 para evitar o overfit no bloco Val
final_epochs = int(best_epoch * 0.8)

# Reduza as Épocas com um Fator de Desconto
# Treinar o número exato de best_epoch em um conjunto de dados maior quase sempre causa overfitting.
# Uma regra prática de Deep Learning para séries temporais é treinar entre 70% a 80% das épocas originais
# quando adicionamos a validação ao treino, ou aplicar uma taxa de aprendizado menor.

print(f"A melhor performance foi na época: {best_epoch}")
print(f"A melhor performance ajustada foi na época: {final_epochs}")
# Out:
# A melhor performance foi na época: 22
# A melhor performance ajustada foi na época: 17

# %%
# Re-treinar o modelo com o conjunto completo
model_lstm_agg = lstm_model(X_train_lstm)

# %%
# Use o número de épocas que o Early Stopping encontrou anteriormente
start_time = time.time()
history = model_lstm_agg.fit(
    X_final_train, y_final_train,
    epochs=final_epochs, # Ou o melhor valor encontrado pelo early_stop
    batch_size=32,
    verbose=1
    # Sem validation_data aqui, pois você uniu tudo para ganhar poder estatístico
)
end_time = time.time()
# Out:
# Epoch 1/17
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 0.5439
# Epoch 2/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.2663
# Epoch 3/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1970
# Epoch 4/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1773
# Epoch 5/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1651
# Epoch 6/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1561
# Epoch 7/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.1517
# Epoch 8/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1460
# Epoch 9/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1409
# Epoch 10/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1393
# Epoch 11/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1324
# Epoch 12/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1285
# Epoch 13/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1241
# Epoch 14/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1269
# Epoch 15/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1200
# Epoch 16/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1178
# Epoch 17/17
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1196

# %%
# Prever o Teste (O "mundo real" que o modelo nunca viu)
y_pred_test_scaled_final = model_lstm_agg.predict(X_test_lstm)
y_pred_test_final = scaler_y.inverse_transform(y_pred_test_scaled_final)
# y_pred_test_final = scaler_y_novo.inverse_transform(y_pred_test_scaled_final)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 589ms/step

# %%
y_pred_test_final_ = pd.DataFrame(y_pred_test_final, columns=[column_target], index=y_test.index)

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test.index, y_test, label='Real',  color='green', lw=2)
plt.plot(y_test.index, y_pred_test_final_, label='Previsto', color='orange', lw=2)
plt.title(f"{model_name} Aggregate Train + Val - Previsão vs Real (Test)")
plt.xlabel("Date")
plt.ylabel("Total de Casos")
plt.legend()
plt.show()

# %%
metrics_ = dict()
metrics_ = get_erros_metric(y_test, y_pred_test_final_, (end_time - start_time))
df_result = add_resultado(df_result, f'{model_name}_test_agg', metrics_)
df_result
# Out:
#             Type      Start        End        MAE         MSE       RMSE  \
# 0       LSTM_val 2025-08-27 2025-12-24   6.791340   75.001892   8.660363
# 1      LSTM_test 2025-12-25 2026-04-23   9.783911  192.986719  13.891966
# 2  LSTM_test_agg 2025-12-25 2026-04-23  20.394504  693.383725  26.332180
#
#           R2    Seconds
# 0  -8.260763  86.121819
# 1  -5.856265  86.121819
# 2 -23.633936  47.383656

# %%
# Usando seus dados já devidamente escalados previamente
X_completo = X_final_train
y_completo = y_final_train

tscv = TimeSeriesSplit(n_splits=50, max_train_size=None)
# tscv = TimeSeriesSplit(n_splits=50, max_train_size=365)
fold = 1
fold_losses = []
best_model = None
importancias_acumuladas = []

print("🚀 Iniciando Treino Temporal Inteligente...")

for train_index, val_index in tscv.split(X_completo):
    # Separação estrita baseada na linha do tempo
    X_train_fold, X_val_fold = X_completo[train_index], X_completo[val_index]
    y_train_fold, y_val_fold = y_completo[train_index], y_completo[val_index]

    # Instancia um modelo zerado para este bloco temporal
    model = lstm_model(X_train_fold)

    # ATIVAÇÃO DOS CALLBACKS: Crucial para o modelo não estagnar/viciar
    # callbacks = [
    #     # Se parar de melhorar por 7 épocas, interrompe para não "decorar" a média
    #     EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True),
    #     # Se estagnar, reduz o learning rate para tentar achar padrões locais refinados
    #     ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-5)
    # ]

    # Treina usando as variáveis puras (já escaladas por você antes)
    model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        epochs=500, # Reduzido ligeiramente o teto para evitar overfit severo
        batch_size=32,
        verbose=1, # Mude para 1 se quiser acompanhar se a perda (loss) está caindo de verdade
        callbacks=callbacks
    )

    val_loss = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    fold_losses.append(val_loss)
    print(f"Fold {fold} - Val Loss (Huber): {val_loss:.4f}")

    # Captura o último fold (o modelo que viu o máximo de histórico possível)
    if fold == tscv.n_splits:
        model_lstm_roll = model

    fold += 1

print("\n--- 📊 FIM DA VALIDAÇÃO CRUZADA ---")
print(f"Média do Huber Loss nos 5 períodos: {np.mean(fold_losses):.4f}")
# Out:
# 🚀 Iniciando Treino Temporal Inteligente...
# Epoch 1/500
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 729ms/step - loss: 0.5813 - val_loss: 0.0422 - learning_rate: 0.0010
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6820 - val_loss: 0.0311 - learning_rate: 0.0010
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5460 - val_loss: 0.0221 - learning_rate: 0.0010
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5928 - val_loss: 0.0151 - learning_rate: 0.0010
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5127 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4353 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 7/500
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3470
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4339 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4264 - val_loss: 0.0023 - learning_rate: 5.0000e-04
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.3961 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.3959 - val_loss: 4.1909e-04 - learning_rate: 5.0000e-04
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3878 - val_loss: 1.1610e-04 - learning_rate: 5.0000e-04
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3502 - val_loss: 9.0187e-05 - learning_rate: 5.0000e-04
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3119 - val_loss: 4.6117e-04 - learning_rate: 5.0000e-04
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4348 - val_loss: 8.3561e-04 - learning_rate: 5.0000e-04
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2772 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2472 - val_loss: 0.0021 - learning_rate: 5.0000e-04
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3345 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 18/500
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2772
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2654 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2215 - val_loss: 0.0046 - learning_rate: 2.5000e-04
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2452 - val_loss: 0.0055 - learning_rate: 2.5000e-04
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3109 - val_loss: 0.0066 - learning_rate: 2.5000e-04
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3186 - val_loss: 0.0072 - learning_rate: 2.5000e-04
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2170 - val_loss: 0.0081 - learning_rate: 2.5000e-04
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2342 - val_loss: 0.0091 - learning_rate: 2.5000e-04
# Epoch 25/500
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2091
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2292 - val_loss: 0.0102 - learning_rate: 2.5000e-04
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2926 - val_loss: 0.0110 - learning_rate: 1.2500e-04
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2294 - val_loss: 0.0120 - learning_rate: 1.2500e-04
# Fold 1 - Val Loss (Huber): 0.0001
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 731ms/step - loss: 0.9497 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.8600 - val_loss: 0.0363 - learning_rate: 0.0010
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6482 - val_loss: 0.0270 - learning_rate: 0.0010
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7770 - val_loss: 0.0197 - learning_rate: 0.0010
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.6496 - val_loss: 0.0140 - learning_rate: 0.0010
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.6455 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4816
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.5124 - val_loss: 0.0067 - learning_rate: 0.0010
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.5324 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4400 - val_loss: 0.0031 - learning_rate: 5.0000e-04
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3433 - val_loss: 0.0022 - learning_rate: 5.0000e-04
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4683 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4184 - val_loss: 9.9036e-04 - learning_rate: 5.0000e-04
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.3487 - val_loss: 4.6174e-04 - learning_rate: 5.0000e-04
# Epoch 14/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3317
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3640 - val_loss: 2.0046e-04 - learning_rate: 5.0000e-04
# Epoch 15/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3679 - val_loss: 1.0697e-04 - learning_rate: 2.5000e-04
# Fold 2 - Val Loss (Huber): 0.0472
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 376ms/step - loss: 0.4940 - val_loss: 0.0539 - learning_rate: 0.0010
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4895 - val_loss: 0.0442 - learning_rate: 0.0010
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3846 - val_loss: 0.0362 - learning_rate: 0.0010
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4378 - val_loss: 0.0300 - learning_rate: 0.0010
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3251 - val_loss: 0.0248 - learning_rate: 0.0010
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3155 - val_loss: 0.0190 - learning_rate: 0.0010
# Epoch 7/500
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3125
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2678 - val_loss: 0.0148 - learning_rate: 0.0010
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2162 - val_loss: 0.0130 - learning_rate: 5.0000e-04
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3131 - val_loss: 0.0102 - learning_rate: 5.0000e-04
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2126 - val_loss: 0.0080 - learning_rate: 5.0000e-04
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2337 - val_loss: 0.0059 - learning_rate: 5.0000e-04
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1766 - val_loss: 0.0039 - learning_rate: 5.0000e-04
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1727 - val_loss: 0.0023 - learning_rate: 5.0000e-04
# Epoch 14/500
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1700
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1707 - val_loss: 0.0012 - learning_rate: 5.0000e-04
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2119 - val_loss: 6.3517e-04 - learning_rate: 2.5000e-04
# Fold 3 - Val Loss (Huber): 0.0539
# Epoch 1/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 363ms/step - loss: 0.6693 - val_loss: 0.0469 - learning_rate: 0.0010
# Epoch 2/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5561 - val_loss: 0.0309 - learning_rate: 0.0010
# Epoch 3/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4653 - val_loss: 0.0203 - learning_rate: 0.0010
# Epoch 4/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5198 - val_loss: 0.0129 - learning_rate: 0.0010
# Epoch 5/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4377 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 6/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3178 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 7/500
# 4/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3810
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3859 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 8/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3059 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 9/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2722 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 10/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2532 - val_loss: 6.6735e-04 - learning_rate: 5.0000e-04
# Epoch 11/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2901 - val_loss: 5.0009e-04 - learning_rate: 5.0000e-04
# Epoch 12/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2810 - val_loss: 4.4803e-04 - learning_rate: 5.0000e-04
# Epoch 13/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2536 - val_loss: 5.1568e-04 - learning_rate: 5.0000e-04
# Epoch 14/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2454
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2519 - val_loss: 6.4960e-04 - learning_rate: 5.0000e-04
# Epoch 15/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2314 - val_loss: 8.6563e-04 - learning_rate: 2.5000e-04
# Fold 4 - Val Loss (Huber): 0.0469
# Epoch 1/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 225ms/step - loss: 0.8494 - val_loss: 0.0502 - learning_rate: 0.0010
# Epoch 2/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.7696 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 3/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5333 - val_loss: 0.0323 - learning_rate: 0.0010
# Epoch 4/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4560 - val_loss: 0.0221 - learning_rate: 0.0010
# Epoch 5/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4578 - val_loss: 0.0128 - learning_rate: 0.0010
# Epoch 6/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3446 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 7/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2280
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2327 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 8/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2805 - val_loss: 4.4154e-04 - learning_rate: 5.0000e-04
# Epoch 9/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2613 - val_loss: 2.9634e-04 - learning_rate: 5.0000e-04
# Epoch 10/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2696 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 11/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2233 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 12/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1801 - val_loss: 0.0050 - learning_rate: 5.0000e-04
# Epoch 13/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1958 - val_loss: 0.0074 - learning_rate: 5.0000e-04
# Epoch 14/500
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1902
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.1798 - val_loss: 0.0111 - learning_rate: 5.0000e-04
# Epoch 15/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1888 - val_loss: 0.0129 - learning_rate: 2.5000e-04
# Fold 5 - Val Loss (Huber): 0.0502
# Epoch 1/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 19s 196ms/step - loss: 0.6957 - val_loss: 0.0186 - learning_rate: 0.0010
# Epoch 2/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6499 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 3/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4735 - val_loss: 4.9215e-04 - learning_rate: 0.0010
# Epoch 4/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4772 - val_loss: 3.9719e-04 - learning_rate: 0.0010
# Epoch 5/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3981 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 6/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3274 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 7/500
# 7/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2960
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2543 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 8/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2342 - val_loss: 0.0040 - learning_rate: 5.0000e-04
# Epoch 9/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1878 - val_loss: 0.0046 - learning_rate: 5.0000e-04
# Epoch 10/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2021 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 11/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2026 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 12/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1558 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 13/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1723 - val_loss: 0.0025 - learning_rate: 5.0000e-04
# Epoch 14/500
# 7/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1492
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1309 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 15/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1655 - val_loss: 0.0013 - learning_rate: 2.5000e-04
# Fold 6 - Val Loss (Huber): 0.0186
# Epoch 1/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 246ms/step - loss: 0.5223 - val_loss: 0.0408 - learning_rate: 0.0010
# Epoch 2/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.4233 - val_loss: 0.0296 - learning_rate: 0.0010
# Epoch 3/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.2923 - val_loss: 0.0195 - learning_rate: 0.0010
# Epoch 4/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2575 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 5/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2013 - val_loss: 0.0058 - learning_rate: 0.0010
# Epoch 6/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1841 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 7/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1147
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1123 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 8/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1102 - val_loss: 0.0023 - learning_rate: 5.0000e-04
# Epoch 9/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1118 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 10/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1025 - val_loss: 0.0030 - learning_rate: 5.0000e-04
# Epoch 11/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0836 - val_loss: 0.0025 - learning_rate: 5.0000e-04
# Epoch 12/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0807 - val_loss: 0.0027 - learning_rate: 5.0000e-04
# Epoch 13/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0781 - val_loss: 0.0026 - learning_rate: 5.0000e-04
# Epoch 14/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0726
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0736 - val_loss: 0.0026 - learning_rate: 5.0000e-04
# Epoch 15/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0843 - val_loss: 0.0030 - learning_rate: 2.5000e-04
# Fold 7 - Val Loss (Huber): 0.0408
# Epoch 1/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - loss: 0.6734 - val_loss: 0.0205 - learning_rate: 0.0010
# Epoch 2/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5006 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 3/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.4107 - val_loss: 4.2306e-04 - learning_rate: 0.0010
# Epoch 4/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.2882 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 5/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.2507 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 6/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.1856 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 7/500
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1512
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1665 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 8/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.1474 - val_loss: 0.0024 - learning_rate: 5.0000e-04
# Epoch 9/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1468 - val_loss: 0.0030 - learning_rate: 5.0000e-04
# Epoch 10/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1146 - val_loss: 0.0047 - learning_rate: 5.0000e-04
# Epoch 11/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1147 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 12/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1072 - val_loss: 0.0068 - learning_rate: 5.0000e-04
# Epoch 13/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1012 - val_loss: 0.0067 - learning_rate: 5.0000e-04
# Epoch 14/500
# 10/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1030
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0978 - val_loss: 0.0062 - learning_rate: 5.0000e-04
# Epoch 15/500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0943 - val_loss: 0.0057 - learning_rate: 2.5000e-04
# Fold 8 - Val Loss (Huber): 0.0205
# Epoch 1/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 138ms/step - loss: 0.5815 - val_loss: 0.0167 - learning_rate: 0.0010
# Epoch 2/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4188 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 3/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2792 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 4/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2122 - val_loss: 8.0343e-04 - learning_rate: 0.0010
# Epoch 5/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1842 - val_loss: 4.3553e-04 - learning_rate: 0.0010
# Epoch 6/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1261 - val_loss: 6.9641e-04 - learning_rate: 0.0010
# Epoch 7/500
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1158
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1107 - val_loss: 7.5774e-04 - learning_rate: 0.0010
# Epoch 8/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0962 - val_loss: 6.8452e-04 - learning_rate: 5.0000e-04
# Epoch 9/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0809 - val_loss: 7.5301e-04 - learning_rate: 5.0000e-04
# Epoch 10/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0819 - val_loss: 8.5398e-04 - learning_rate: 5.0000e-04
# Epoch 11/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0815 - val_loss: 8.8249e-04 - learning_rate: 5.0000e-04
# Epoch 12/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0746 - val_loss: 0.0013 - learning_rate: 5.0000e-04
# Epoch 13/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0650 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 14/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0664
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0627 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 15/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0506 - val_loss: 0.0017 - learning_rate: 2.5000e-04
# Fold 9 - Val Loss (Huber): 0.0167
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 129ms/step - loss: 0.6514 - val_loss: 0.0397 - learning_rate: 0.0010
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4878 - val_loss: 0.0285 - learning_rate: 0.0010
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3079 - val_loss: 0.0228 - learning_rate: 0.0010
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2758 - val_loss: 0.0181 - learning_rate: 0.0010
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1918 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1747 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 7/500
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1421
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1381 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1122 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1124 - val_loss: 0.0037 - learning_rate: 5.0000e-04
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0922 - val_loss: 0.0040 - learning_rate: 5.0000e-04
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0826 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Epoch 12/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0829 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 13/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0690 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 14/500
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0667
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0733 - val_loss: 0.0050 - learning_rate: 5.0000e-04
# Epoch 15/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0582 - val_loss: 0.0043 - learning_rate: 2.5000e-04
# Fold 10 - Val Loss (Huber): 0.0397
# Epoch 1/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 22s 158ms/step - loss: 0.6804 - val_loss: 0.0105 - learning_rate: 0.0010
# Epoch 2/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.5499 - val_loss: 1.2381e-04 - learning_rate: 0.0010
# Epoch 3/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4683 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 4/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3673 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 5/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2705 - val_loss: 0.0186 - learning_rate: 0.0010
# Epoch 6/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2507 - val_loss: 0.0182 - learning_rate: 0.0010
# Epoch 7/500
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2035
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1938 - val_loss: 0.0128 - learning_rate: 0.0010
# Epoch 8/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1734 - val_loss: 0.0142 - learning_rate: 5.0000e-04
# Epoch 9/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1566 - val_loss: 0.0146 - learning_rate: 5.0000e-04
# Epoch 10/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1380 - val_loss: 0.0136 - learning_rate: 5.0000e-04
# Epoch 11/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1264 - val_loss: 0.0115 - learning_rate: 5.0000e-04
# Epoch 12/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1000 - val_loss: 0.0090 - learning_rate: 5.0000e-04
# Epoch 13/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1152 - val_loss: 0.0064 - learning_rate: 5.0000e-04
# Epoch 14/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1214
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1067 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 15/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0936 - val_loss: 0.0052 - learning_rate: 2.5000e-04
# Fold 11 - Val Loss (Huber): 0.0105
# Epoch 1/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 120ms/step - loss: 0.6302 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 2/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.4658 - val_loss: 5.9010e-04 - learning_rate: 0.0010
# Epoch 3/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3205 - val_loss: 1.6189e-04 - learning_rate: 0.0010
# Epoch 4/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.2238 - val_loss: 5.8831e-04 - learning_rate: 0.0010
# Epoch 5/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.1900 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 6/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.1432 - val_loss: 5.8563e-04 - learning_rate: 0.0010
# Epoch 7/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1337
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.1353 - val_loss: 3.6718e-04 - learning_rate: 0.0010
# Epoch 8/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1271 - val_loss: 9.0999e-04 - learning_rate: 5.0000e-04
# Epoch 9/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1023 - val_loss: 8.2866e-04 - learning_rate: 5.0000e-04
# Epoch 10/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0968 - val_loss: 6.7296e-04 - learning_rate: 5.0000e-04
# Epoch 11/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0827 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 12/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0759 - val_loss: 0.0025 - learning_rate: 5.0000e-04
# Epoch 13/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0646 - val_loss: 0.0042 - learning_rate: 5.0000e-04
# Epoch 14/500
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0623
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0590 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 15/500
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0605 - val_loss: 0.0068 - learning_rate: 2.5000e-04
# Fold 12 - Val Loss (Huber): 0.0087
# Epoch 1/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 19s 103ms/step - loss: 0.6896 - val_loss: 0.0466 - learning_rate: 0.0010
# Epoch 2/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4598 - val_loss: 0.0265 - learning_rate: 0.0010
# Epoch 3/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3269 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 4/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2361 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 5/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1538 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 6/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1170 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 7/500
# 17/18 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1291
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.1170 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 8/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0731 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 9/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0727 - val_loss: 0.0061 - learning_rate: 5.0000e-04
# Epoch 10/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0589 - val_loss: 0.0064 - learning_rate: 5.0000e-04
# Epoch 11/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0580 - val_loss: 0.0066 - learning_rate: 5.0000e-04
# Epoch 12/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0504 - val_loss: 0.0073 - learning_rate: 5.0000e-04
# Epoch 13/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0494 - val_loss: 0.0086 - learning_rate: 5.0000e-04
# Epoch 14/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0452
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0437 - val_loss: 0.0093 - learning_rate: 5.0000e-04
# Epoch 15/500
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0394 - val_loss: 0.0103 - learning_rate: 2.5000e-04
# Fold 13 - Val Loss (Huber): 0.0466
# Epoch 1/500
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 96ms/step - loss: 0.4721 - val_loss: 0.0493 - learning_rate: 0.0010
# Epoch 2/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3123 - val_loss: 0.0389 - learning_rate: 0.0010
# Epoch 3/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2138 - val_loss: 0.0217 - learning_rate: 0.0010
# Epoch 4/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1416 - val_loss: 0.0102 - learning_rate: 0.0010
# Epoch 5/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1058 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 6/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0850 - val_loss: 5.9350e-04 - learning_rate: 0.0010
# Epoch 7/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0615
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0610 - val_loss: 8.4543e-04 - learning_rate: 0.0010
# Epoch 8/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0488 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 9/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0429 - val_loss: 0.0026 - learning_rate: 5.0000e-04
# Epoch 10/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0430 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 11/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0371 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 12/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0346 - val_loss: 0.0060 - learning_rate: 5.0000e-04
# Epoch 13/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0323 - val_loss: 0.0061 - learning_rate: 5.0000e-04
# Epoch 14/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0300
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0298 - val_loss: 0.0066 - learning_rate: 5.0000e-04
# Epoch 15/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0266 - val_loss: 0.0062 - learning_rate: 2.5000e-04
# Fold 14 - Val Loss (Huber): 0.0493
# Epoch 1/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 0.5050 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 2/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3065 - val_loss: 3.3506e-04 - learning_rate: 0.0010
# Epoch 3/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2050 - val_loss: 5.2440e-04 - learning_rate: 0.0010
# Epoch 4/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1460 - val_loss: 7.2171e-04 - learning_rate: 0.0010
# Epoch 5/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0865 - val_loss: 7.0140e-04 - learning_rate: 0.0010
# Epoch 6/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0641 - val_loss: 7.5641e-04 - learning_rate: 0.0010
# Epoch 7/500
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0320
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0310 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 8/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0350 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 9/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0330 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 10/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0262 - val_loss: 0.0024 - learning_rate: 5.0000e-04
# Epoch 11/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0250 - val_loss: 0.0027 - learning_rate: 5.0000e-04
# Epoch 12/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0267 - val_loss: 0.0033 - learning_rate: 5.0000e-04
# Epoch 13/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0185 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 14/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0166
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0172 - val_loss: 0.0027 - learning_rate: 5.0000e-04
# Epoch 15/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0158 - val_loss: 0.0026 - learning_rate: 2.5000e-04
# Fold 15 - Val Loss (Huber): 0.0076
# Epoch 1/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 19s 87ms/step - loss: 0.8707 - val_loss: 0.0136 - learning_rate: 0.0010
# Epoch 2/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5269 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 3/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3795 - val_loss: 3.3483e-04 - learning_rate: 0.0010
# Epoch 4/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2571 - val_loss: 6.8273e-04 - learning_rate: 0.0010
# Epoch 5/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2098 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 6/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1506 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 7/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1300
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1137 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 8/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0805 - val_loss: 0.0031 - learning_rate: 5.0000e-04
# Epoch 9/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0757 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 10/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0666 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 11/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0658 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 12/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0616 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 13/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0547 - val_loss: 0.0043 - learning_rate: 5.0000e-04
# Epoch 14/500
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0656
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0546 - val_loss: 0.0039 - learning_rate: 5.0000e-04
# Epoch 15/500
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0503 - val_loss: 0.0047 - learning_rate: 2.5000e-04
# Fold 16 - Val Loss (Huber): 0.0136
# Epoch 1/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 84ms/step - loss: 0.7205 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 2/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4399 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 3/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2601 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 4/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1889 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 5/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1509 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 6/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1039 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 7/500
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0903
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0870 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 8/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0750 - val_loss: 0.0067 - learning_rate: 5.0000e-04
# Epoch 9/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0694 - val_loss: 0.0073 - learning_rate: 5.0000e-04
# Epoch 10/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0566 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 11/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0491 - val_loss: 0.0082 - learning_rate: 5.0000e-04
# Epoch 12/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0485 - val_loss: 0.0062 - learning_rate: 5.0000e-04
# Epoch 13/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0381 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 14/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0387
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0372 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 15/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0363 - val_loss: 0.0038 - learning_rate: 2.5000e-04
# Fold 17 - Val Loss (Huber): 0.0048
# Epoch 1/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 78ms/step - loss: 0.5997 - val_loss: 0.0191 - learning_rate: 0.0010
# Epoch 2/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.3329 - val_loss: 0.0469 - learning_rate: 0.0010
# Epoch 3/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2269 - val_loss: 0.0649 - learning_rate: 0.0010
# Epoch 4/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1499 - val_loss: 0.0757 - learning_rate: 0.0010
# Epoch 5/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0944 - val_loss: 0.0672 - learning_rate: 0.0010
# Epoch 6/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0766 - val_loss: 0.0611 - learning_rate: 0.0010
# Epoch 7/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0616
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0559 - val_loss: 0.0574 - learning_rate: 0.0010
# Epoch 8/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0407 - val_loss: 0.0514 - learning_rate: 5.0000e-04
# Epoch 9/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0449 - val_loss: 0.0458 - learning_rate: 5.0000e-04
# Epoch 10/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0395 - val_loss: 0.0422 - learning_rate: 5.0000e-04
# Epoch 11/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0343 - val_loss: 0.0423 - learning_rate: 5.0000e-04
# Epoch 12/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0352 - val_loss: 0.0406 - learning_rate: 5.0000e-04
# Epoch 13/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0290 - val_loss: 0.0362 - learning_rate: 5.0000e-04
# Epoch 14/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0269
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0247 - val_loss: 0.0337 - learning_rate: 5.0000e-04
# Epoch 15/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0219 - val_loss: 0.0339 - learning_rate: 2.5000e-04
# Fold 18 - Val Loss (Huber): 0.0191
# Epoch 1/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 77ms/step - loss: 0.7081 - val_loss: 0.0174 - learning_rate: 0.0010
# Epoch 2/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4620 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 3/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2767 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 4/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2054 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 5/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1336 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 6/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1038 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 7/500
# 24/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0862
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0795 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 8/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0692 - val_loss: 0.0056 - learning_rate: 5.0000e-04
# Epoch 9/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0646 - val_loss: 0.0069 - learning_rate: 5.0000e-04
# Epoch 10/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0566 - val_loss: 0.0076 - learning_rate: 5.0000e-04
# Epoch 11/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0528 - val_loss: 0.0076 - learning_rate: 5.0000e-04
# Epoch 12/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0477 - val_loss: 0.0068 - learning_rate: 5.0000e-04
# Epoch 13/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0395 - val_loss: 0.0051 - learning_rate: 5.0000e-04
# Epoch 14/500
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0388
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0373 - val_loss: 0.0052 - learning_rate: 5.0000e-04
# Epoch 15/500
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0351 - val_loss: 0.0055 - learning_rate: 2.5000e-04
# Fold 19 - Val Loss (Huber): 0.0174
# Epoch 1/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - loss: 0.4211 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 2/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2534 - val_loss: 6.6251e-04 - learning_rate: 0.0010
# Epoch 3/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1573 - val_loss: 9.1593e-04 - learning_rate: 0.0010
# Epoch 4/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0942 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 5/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0615 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 6/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0451 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 7/500
# 25/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0475
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0424 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 8/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0342 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 9/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0316 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 10/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0261 - val_loss: 0.0012 - learning_rate: 5.0000e-04
# Epoch 11/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0246 - val_loss: 9.5293e-04 - learning_rate: 5.0000e-04
# Epoch 12/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0237 - val_loss: 9.9979e-04 - learning_rate: 5.0000e-04
# Epoch 13/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0217 - val_loss: 9.6142e-04 - learning_rate: 5.0000e-04
# Epoch 14/500
# 25/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0187
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0185 - val_loss: 9.4532e-04 - learning_rate: 5.0000e-04
# Epoch 15/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0199 - val_loss: 0.0012 - learning_rate: 2.5000e-04
# Fold 20 - Val Loss (Huber): 0.0032
# Epoch 1/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - loss: 0.7152 - val_loss: 0.0106 - learning_rate: 0.0010
# Epoch 2/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4101 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 3/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2843 - val_loss: 6.0615e-04 - learning_rate: 0.0010
# Epoch 4/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2025 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 5/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1307 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 6/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0883 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 7/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0650
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0602 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 8/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0595 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 9/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0486 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 10/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0432 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 11/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0388 - val_loss: 0.0067 - learning_rate: 5.0000e-04
# Epoch 12/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0348 - val_loss: 0.0051 - learning_rate: 5.0000e-04
# Epoch 13/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0337 - val_loss: 0.0032 - learning_rate: 5.0000e-04
# Epoch 14/500
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0290
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0299 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Epoch 15/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0289 - val_loss: 0.0033 - learning_rate: 2.5000e-04
# Fold 21 - Val Loss (Huber): 0.0106
# Epoch 1/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 66ms/step - loss: 0.5037 - val_loss: 0.0129 - learning_rate: 0.0010
# Epoch 2/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2502 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 3/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1289 - val_loss: 5.4911e-04 - learning_rate: 0.0010
# Epoch 4/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0861 - val_loss: 8.4987e-04 - learning_rate: 0.0010
# Epoch 5/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0553 - val_loss: 3.3758e-04 - learning_rate: 0.0010
# Epoch 6/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0369 - val_loss: 2.9602e-04 - learning_rate: 0.0010
# Epoch 7/500
# 29/30 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0308
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0289 - val_loss: 3.8004e-04 - learning_rate: 0.0010
# Epoch 8/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0271 - val_loss: 4.3892e-04 - learning_rate: 5.0000e-04
# Epoch 9/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0236 - val_loss: 5.8892e-04 - learning_rate: 5.0000e-04
# Epoch 10/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0229 - val_loss: 8.5526e-04 - learning_rate: 5.0000e-04
# Epoch 11/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0212 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 12/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0173 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 13/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0162 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 14/500
# 28/30 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0147
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0146 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 15/500
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0137 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Fold 22 - Val Loss (Huber): 0.0129
# Epoch 1/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 67ms/step - loss: 0.5592 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 2/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.3082 - val_loss: 4.2337e-04 - learning_rate: 0.0010
# Epoch 3/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1755 - val_loss: 4.1397e-04 - learning_rate: 0.0010
# Epoch 4/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1041 - val_loss: 7.6843e-04 - learning_rate: 0.0010
# Epoch 5/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0750 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 6/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0448 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 7/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0424
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0387 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 8/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0300 - val_loss: 0.0031 - learning_rate: 5.0000e-04
# Epoch 9/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0292 - val_loss: 0.0031 - learning_rate: 5.0000e-04
# Epoch 10/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0222 - val_loss: 0.0027 - learning_rate: 5.0000e-04
# Epoch 11/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0238 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 12/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0218 - val_loss: 0.0026 - learning_rate: 5.0000e-04
# Epoch 13/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0200 - val_loss: 0.0026 - learning_rate: 5.0000e-04
# Epoch 14/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0183
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0191 - val_loss: 0.0026 - learning_rate: 5.0000e-04
# Epoch 15/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0182 - val_loss: 0.0027 - learning_rate: 2.5000e-04
# Fold 23 - Val Loss (Huber): 0.0077
# Epoch 1/500
# ...
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - loss: 0.6113 - val_loss: 0.0576 - learning_rate: 0.0010
# Epoch 2/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.3394 - val_loss: 0.0999 - learning_rate: 0.0010
# Epoch 3/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2493 - val_loss: 0.0794 - learning_rate: 0.0010
# Epoch 4/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2088 - val_loss: 0.0343 - learning_rate: 0.0010
# Epoch 5/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1871 - val_loss: 0.0229 - learning_rate: 0.0010
# Epoch 6/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1759 - val_loss: 0.0402 - learning_rate: 0.0010
# Epoch 7/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1744
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1682 - val_loss: 0.0466 - learning_rate: 0.0010
# Epoch 8/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1696 - val_loss: 0.0564 - learning_rate: 5.0000e-04
# Epoch 9/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1720 - val_loss: 0.0581 - learning_rate: 5.0000e-04
# Epoch 10/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1573 - val_loss: 0.0705 - learning_rate: 5.0000e-04
# Epoch 11/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.1567 - val_loss: 0.0805 - learning_rate: 5.0000e-04
# Epoch 12/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.1461 - val_loss: 0.0684 - learning_rate: 5.0000e-04
# Epoch 13/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.1474 - val_loss: 0.0679 - learning_rate: 5.0000e-04
# Epoch 14/500
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1515
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1495 - val_loss: 0.0580 - learning_rate: 5.0000e-04
# Epoch 15/500
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1433 - val_loss: 0.0473 - learning_rate: 2.5000e-04
# Fold 43 - Val Loss (Huber): 0.0576
# Epoch 1/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - loss: 0.6346 - val_loss: 0.0060 - learning_rate: 0.0010
# Epoch 2/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3448 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 3/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.2531 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 4/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.2157 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 5/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1968 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 6/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1862 - val_loss: 0.0097 - learning_rate: 0.0010
# Epoch 7/500
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1694
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1731 - val_loss: 0.0334 - learning_rate: 0.0010
# Epoch 8/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1627 - val_loss: 0.0497 - learning_rate: 5.0000e-04
# Epoch 9/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1620 - val_loss: 0.0601 - learning_rate: 5.0000e-04
# Epoch 10/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1609 - val_loss: 0.0557 - learning_rate: 5.0000e-04
# Epoch 11/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1637 - val_loss: 0.0355 - learning_rate: 5.0000e-04
# Epoch 12/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.1529 - val_loss: 0.0372 - learning_rate: 5.0000e-04
# Epoch 13/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.1521 - val_loss: 0.0471 - learning_rate: 5.0000e-04
# Epoch 14/500
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1525
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1517 - val_loss: 0.0605 - learning_rate: 5.0000e-04
# Epoch 15/500
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1495 - val_loss: 0.0724 - learning_rate: 2.5000e-04
# Fold 44 - Val Loss (Huber): 0.0060
# Epoch 1/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - loss: 0.5034 - val_loss: 0.0127 - learning_rate: 0.0010
# Epoch 2/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2742 - val_loss: 0.0254 - learning_rate: 0.0010
# Epoch 3/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2235 - val_loss: 0.0224 - learning_rate: 0.0010
# Epoch 4/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1962 - val_loss: 0.0186 - learning_rate: 0.0010
# Epoch 5/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.1821 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 6/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1716 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 7/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1769
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1632 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 8/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1553 - val_loss: 0.0050 - learning_rate: 5.0000e-04
# Epoch 9/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1525 - val_loss: 0.0053 - learning_rate: 5.0000e-04
# Epoch 10/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1436 - val_loss: 0.0084 - learning_rate: 5.0000e-04
# Epoch 11/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1477 - val_loss: 0.0079 - learning_rate: 5.0000e-04
# Epoch 12/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1429 - val_loss: 0.0085 - learning_rate: 5.0000e-04
# Epoch 13/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1412 - val_loss: 0.0114 - learning_rate: 5.0000e-04
# Epoch 14/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1551
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1418 - val_loss: 0.0073 - learning_rate: 5.0000e-04
# Epoch 15/500
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.1340 - val_loss: 0.0094 - learning_rate: 2.5000e-04
# Fold 45 - Val Loss (Huber): 0.0127
# Epoch 1/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 44ms/step - loss: 0.6011 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 2/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2967 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 3/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2263 - val_loss: 0.0167 - learning_rate: 0.0010
# Epoch 4/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2008 - val_loss: 0.0176 - learning_rate: 0.0010
# Epoch 5/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1814 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 6/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1726 - val_loss: 0.0058 - learning_rate: 0.0010
# Epoch 7/500
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1338
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1570 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 8/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.1538 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 9/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.1480 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 10/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1513 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 11/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1468 - val_loss: 0.0105 - learning_rate: 5.0000e-04
# Epoch 12/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1454 - val_loss: 0.0114 - learning_rate: 5.0000e-04
# Epoch 13/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1434 - val_loss: 0.0099 - learning_rate: 5.0000e-04
# Epoch 14/500
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1188
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1366 - val_loss: 0.0115 - learning_rate: 5.0000e-04
# Epoch 15/500
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1323 - val_loss: 0.0118 - learning_rate: 2.5000e-04
# Fold 46 - Val Loss (Huber): 0.0049
# Epoch 1/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - loss: 0.3951 - val_loss: 0.0135 - learning_rate: 0.0010
# Epoch 2/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2459 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2022 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 4/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1846 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 5/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1782 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1614 - val_loss: 0.0068 - learning_rate: 0.0010
# Epoch 7/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1861
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1578 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 8/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.1491 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 9/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1492 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1465 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 11/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1434 - val_loss: 0.0046 - learning_rate: 5.0000e-04
# Epoch 12/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1412 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Epoch 13/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1432 - val_loss: 0.0033 - learning_rate: 5.0000e-04
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1721
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1409 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1385 - val_loss: 0.0035 - learning_rate: 2.5000e-04
# Fold 47 - Val Loss (Huber): 0.0135
# Epoch 1/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 28s 47ms/step - loss: 0.4971 - val_loss: 0.0131 - learning_rate: 0.0010
# Epoch 2/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2547 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 3/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1990 - val_loss: 9.1415e-04 - learning_rate: 0.0010
# Epoch 4/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.1731 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 5/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.1650 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 6/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.1562 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 7/500
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1475
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1521 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 8/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1430 - val_loss: 7.6310e-04 - learning_rate: 5.0000e-04
# Epoch 9/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1403 - val_loss: 8.8489e-04 - learning_rate: 5.0000e-04
# Epoch 10/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1383 - val_loss: 6.0488e-04 - learning_rate: 5.0000e-04
# Epoch 11/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.1379 - val_loss: 5.6444e-04 - learning_rate: 5.0000e-04
# Epoch 12/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.1336 - val_loss: 6.8940e-04 - learning_rate: 5.0000e-04
# Epoch 13/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.1301 - val_loss: 5.7552e-04 - learning_rate: 5.0000e-04
# Epoch 14/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1254
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1310 - val_loss: 5.2726e-04 - learning_rate: 5.0000e-04
# Epoch 15/500
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1321 - val_loss: 5.1721e-04 - learning_rate: 2.5000e-04
# Fold 48 - Val Loss (Huber): 0.0131
# Epoch 1/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 22s 66ms/step - loss: 0.5608 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 2/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.3044 - val_loss: 0.0224 - learning_rate: 0.0010
# Epoch 3/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2178 - val_loss: 0.0370 - learning_rate: 0.0010
# Epoch 4/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1973 - val_loss: 0.0175 - learning_rate: 0.0010
# Epoch 5/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1752 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 6/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1663 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 7/500
# 62/64 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1521
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1577 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 8/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1471 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 9/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1433 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 10/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.1461 - val_loss: 0.0061 - learning_rate: 5.0000e-04
# Epoch 11/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1431 - val_loss: 0.0067 - learning_rate: 5.0000e-04
# Epoch 12/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1384 - val_loss: 0.0051 - learning_rate: 5.0000e-04
# Epoch 13/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1331 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 14/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1255
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1353 - val_loss: 0.0052 - learning_rate: 5.0000e-04
# Epoch 15/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1308 - val_loss: 0.0051 - learning_rate: 2.5000e-04
# Fold 49 - Val Loss (Huber): 0.0010
# Epoch 1/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 22s 66ms/step - loss: 0.4507 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 2/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.2637 - val_loss: 0.0188 - learning_rate: 0.0010
# Epoch 3/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1994 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 4/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1713 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 5/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1599 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 6/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1533 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 7/500
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1182
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1512 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 8/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.1428 - val_loss: 0.0041 - learning_rate: 5.0000e-04
# Epoch 9/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.1428 - val_loss: 0.0046 - learning_rate: 5.0000e-04
# Epoch 10/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1419 - val_loss: 0.0043 - learning_rate: 5.0000e-04
# Epoch 11/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1358 - val_loss: 0.0050 - learning_rate: 5.0000e-04
# Epoch 12/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1327 - val_loss: 0.0055 - learning_rate: 5.0000e-04
# Epoch 13/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1328 - val_loss: 0.0068 - learning_rate: 5.0000e-04
# Epoch 14/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1004
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1323 - val_loss: 0.0090 - learning_rate: 5.0000e-04
# Epoch 15/500
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1317 - val_loss: 0.0083 - learning_rate: 2.5000e-04
# Fold 50 - Val Loss (Huber): 0.0113
#
# --- 📊 FIM DA VALIDAÇÃO CRUZADA ---
# Média do Huber Loss nos 5 períodos: 0.2057

# %%
y_pred_test_scaled_final = model_lstm_roll.predict(X_test_lstm)
y_pred_test_roll = scaler_y.inverse_transform(y_pred_test_scaled_final)
# y_pred_test_roll = scaler_y_novo.inverse_transform(y_pred_test_scaled_final)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78d16b8c8f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78d16b8c8f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 570ms/step

# %%
y_pred_test_final_rolling_window = pd.DataFrame(y_pred_test_roll, columns=[column_target], index=y_test.index)

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test.index, y_test, label='Real',  color='green', lw=2)
plt.plot(y_test.index, y_pred_test_final_rolling_window, label='Previsto', color='orange', lw=2)
plt.title(f"{model_name} Rolling Window (Train + Val) - Previsão vs Real (Test)")
plt.xlabel("Date")
plt.ylabel("Total de Casos")
plt.legend()
plt.show()

# %%
metrics_ = dict()
metrics_ = get_erros_metric(y_test, y_pred_test_final_rolling_window, (end_time - start_time))
df_result = add_resultado(df_result, f'{model_name}_test_rolling', metrics_)
df_result
# Out:
#                 Type      Start        End        MAE         MSE       RMSE  \
# 0           LSTM_val 2025-08-27 2025-12-24   6.791340   75.001892   8.660363
# 1          LSTM_test 2025-12-25 2026-04-23   9.783911  192.986719  13.891966
# 2      LSTM_test_agg 2025-12-25 2026-04-23  20.394504  693.383725  26.332180
# 3  LSTM_test_rolling 2025-12-25 2026-04-23  16.003438  290.410602  17.041438
#
#           R2    Seconds
# 0  -8.260763  86.121819
# 1  -5.856265  86.121819
# 2 -23.633936  47.383656
# 3  -9.317456  47.383656

# %% [markdown]
# ## SHAP

# %%
import shap

# %%
def interpretability_shap_lstm(model, X_train_model, X_test_model, train_n_lines=None, test_n_lines=None, nsamples=200, feature_names = X_train_scaled.columns.to_list()):
  # Usa pequena amostra para evitar lentidão
  if train_n_lines == None:
    train_n_lines = round(X_train_model.shape[0] / 3)
  if test_n_lines == None:
    test_n_lines = round(X_test_model.shape[0] / 3)

  X_background = X_train_model[:train_n_lines].reshape(train_n_lines, -1)
  X_test_sample = X_test_model[:test_n_lines].reshape(test_n_lines, -1)

  # Função de predição compatível (reconstrói o formato original esperado pelo modelo)
  def model_predict(x, model, X_train_model):
      # Reajusta o formato para (n_amostras, 1, n_features)
      x_reshaped = x.reshape(x.shape[0], 1, X_train_model.shape[2])
      return model.predict(x_reshaped)

  # Cria o KernelExplainer
  explainer = shap.KernelExplainer(lambda x: model_predict(x, model, X_train_model), X_background)

  # Calcula valores SHAP
  shap_values = explainer.shap_values(X_test_sample, nsamples=nsamples)

  # Flatten das X_test_model
  X_test_plot = X_test_model[:test_n_lines].reshape(test_n_lines, -1)
  shap_plot = shap_values.reshape(test_n_lines, -1)

  # Visualiza a importância média das features
  shap.summary_plot(shap_plot, X_test_plot, feature_names=feature_names)

# %%
# VAL
interpretability_shap_lstm(model_lstm_val, X_train_lstm, X_val_lstm, nsamples=200, feature_names = X_train_scaled.columns.to_list())
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# WARNING:shap:Using 668 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/40 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4175/4175 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step
# /tmp/ipykernel_4882/4207956614.py:28: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_plot, X_test_plot, feature_names=feature_names)

# %%
# Test Agg
interpretability_shap_lstm(model_lstm_agg, X_final_train, X_test_lstm, nsamples=200, feature_names = X_train_scaled.columns.to_list())
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# WARNING:shap:Using 708 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/40 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# /tmp/ipykernel_4882/4207956614.py:28: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_plot, X_test_plot, feature_names=feature_names)

# %%
# Test Rolling
interpretability_shap_lstm(model_lstm_roll, X_final_train, X_test_lstm, nsamples=200, feature_names = X_train_scaled.columns.to_list())
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# WARNING:shap:Using 708 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/40 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4425/4425 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step
# /tmp/ipykernel_4882/4207956614.py:28: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_plot, X_test_plot, feature_names=feature_names)
